# %%
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt 
# from scipy.stats import pearsonr
# from sklearn.linear_model import LogisticRegression 
# import statsmodels.api as sm
# from sklearn.ensemble import RandomForestClassifier

# %%
new_mona = pd.read_excel('../Raw Data/Mona Raw Data 5.21.2020.xlsx')

# %%
for i in new_mona.columns:
    print(new_mona[i].value_counts())
    print("-"*100)
# Out:
# e1811a37-28d4-4579-b2d2-4e727d8c9ee4    1
# 342d6703-12b9-4586-bc39-92860b57c77b    1
# 0429b234-c718-4773-8dcc-13660257e9f9    1
# 30b7408c-7c3c-4d35-a2e7-cfdb1e911a11    1
# cbeb12af-6285-4351-9540-c56fbb18fef0    1
#                                        ..
# e9a6a2ce-26c2-413c-8985-ef3813f2581b    1
# 62b6f53e-2621-4586-9e37-b7238e70857c    1
# adb8f27c-48a2-46e8-b8b0-613336798fe1    1
# 875d0dca-749a-4622-aa6e-5118e1db72e6    1
# 02f38466-0bea-434f-a229-e4aa09cb1759    1
# Name: Contact UUID, Length: 14291, dtype: int64
# ----------------------------------------------------------------------------------------------------
# محمد                    497
# احمد                    251
# محمود                    97
# خالد                     90
# علي                      83
#                        ...
# محمد حمودة                1
# كيبار عبدالله كلكاوي      1
# ميار محمد                 1
# سربند حبيب                1
# عبد الحليم                1
# Name: Name, Length: 9459, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ara    12233
# eng      375
# Name: Language, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 2019-10-16 19:25:50    4
# 2020-02-20 20:30:20    3
# 2019-10-16 19:25:49    3
# 2020-02-20 17:51:39    3
# 2019-10-16 19:25:51    3
#                       ..
# 2020-01-05 23:52:26    1
# 2020-02-28 18:11:38    1
# 2019-11-24 16:52:55    1
# 2020-03-24 03:22:17    1
# 2020-02-20 19:47:21    1
# Name: Created On, Length: 14242, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 2.678372e+15    1
# 2.758223e+15    1
# 2.914418e+15    1
# 2.349822e+15    1
# 3.778452e+15    1
#                ..
# 2.360785e+15    1
# 2.643626e+15    1
# 2.150747e+15    1
# 2.816791e+15    1
# 2.928034e+15    1
# Name: URN:Facebook, Length: 13417, dtype: int64
# ----------------------------------------------------------------------------------------------------
# kald19865     1
# 910657372     1
# 827902694     1
# 233948707     1
# 716318143     1
#              ..
# popravo       1
# alifakhris    1
# 870091433     1
# 917825599     1
# bashar551     1
# Name: URN:Telegram, Length: 874, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 35.0      799
# 30.0      620
# 25.0      492
# 27.0      452
# 32.0      445
#          ...
# 1000.0      1
# 86.0        1
# 1998.0      1
# 1976.0      1
# 71.0        1
# Name: Field:Age, Length: 83, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Male      7287
# Female    2747
# Name: Field:Gender, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Syrian    9558
# Iraqi      229
# Name: Field:Nationality1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Palestinian           27
# Kurd                  23
# Lebanese              12
# لا                     7
# فلسطينية               6
#                       ..
# فلسطينية سورية         1
# إثيوبيا                1
# جنسيتي فلسطيني         1
# قصدى انا كردي سورى     1
# تركمانية               1
# Name: Field:Nationality2, Length: 62, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Nationality3, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Lebanon                     8191
# Jordan                       594
# Turkey                       476
# Iraq                         142
# Egypt                        113
# Syria                        113
# Saudi Arabia                  33
# Sudan                         11
# Libya                          9
# the United Arab Emirates       8
# the United States              5
# Oman                           3
# México.                        3
# Yemen                          2
# Malaysia                       2
# Kenya                          2
# اليونان                        2
# Qatar                          2
# Germany                        2
# Rwanda                         1
# كندا                           1
# Côte d'Ivoire                  1
# قطاع غزة                       1
# Burkina Faso                   1
# Ghana                          1
# جزيرة كوس اليونان              1
# Jessica.                       1
# Thailand                       1
# صربيه                          1
# إيطاليا                        1
# جورجيا تبليسي                  1
# أوكرانيا                       1
# Indonesia                      1
# البرازيل                       1
# the United Kingdom             1
# نعم أنا في إيطاليا             1
# France                         1
# Name: Field:Current Country, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Name: محمد                242
# Name: احمد                107
# Name: اخي                  71
# Name: خالد                 63
# Name: اختي                 53
#                          ...
# Name: جمال حافظ الاسعد      1
# Name: إياد رمضان            1
# Name: دلال سياجان           1
# Name: متابعه                1
# Name: مامو عيس              1
# Name: Field:Relative Abroad Name1, Length: 4125, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Name: محمد                      137
# Name: احمد                       61
# Name: خالد                       33
# Name: محمود                      29
# Name: علي                        29
#                                ...
# Name: محمد العر                   1
# Name: عمي محمود فاعور الشبيب      1
# Name: خالي كمال حسن كرنية         1
# Name: اسامه شنات                  1
# Name: حمزة هماش                   1
# Name: Field:Relative Abroad Name2, Length: 2623, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Name: محمد             53
# Name: احمد             38
# Name: خالد             23
# Name: محمود            20
# Name: علي              16
#                        ..
# Name: لا يوجد           1
# Name: بشير صالحة        1
# Name: فاتن بدر جمول     1
# Name: أيمن الكحيل       1
# Name: بسام ديوان        1
# Name: Field:Relative Abroad Name3, Length: 1482, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Location: Germany                               2205
# Location: Canada                                 916
# Location: Sweden                                 569
# Location: UK                                     370
# Location: United States                          306
#                                                 ...
# Location: أولادي في دولة الدنمارك منذ ٤ سنين       1
# Location: ميوزلندا                                 1
# Location: ايراندا                                  1
# Location: أيرلندى                                  1
# Location: The Nether                               1
# Name: Field:Relative Abroad Location1, Length: 286, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Location: Germany          1292
# Location: Canada            507
# Location: Sweden            406
# Location: United States     198
# Location: UK                182
#                            ...
# Location: دنمرك               1
# Location: الدينمرك            1
# Location: برطاني لعصمي        1
# Location: بورغراس             1
# Location: فرنس                1
# Name: Field:Relative Abroad Location2, Length: 178, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Location: Germany                          711
# Location: Canada                           230
# Location: Sweden                           208
# Location: UK                                93
# Location: Netherlands                       84
#                                           ...
# Location: لا اذكر  نسيت                      1
# Location: لا اعلم بايا بلد ببريطانية         1
# Location: السويد                             1
# Location: ذهب منذ مدة قصيرة إلى ايرلندا      1
# Location: نروج                               1
# Name: Field:Relative Abroad Location3, Length: 104, dtype: int64
# ----------------------------------------------------------------------------------------------------
# محمد                    497
# احمد                    251
# محمود                    97
# خالد                     90
# علي                      83
#                        ...
# الهام حسن محمد            1
# مصطفى طه عبد القادر       1
# ثناء عباس                 1
# خديجه عيسى سليمان         1
# خالديه احمد حاج عقيل      1
# Name: Field:Firstname, Length: 5649, dtype: int64
# ----------------------------------------------------------------------------------------------------
# México    2
# Name: Field:Country Of Origin, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Us Affiliated Relative Name1, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Us Affiliated Relative Name2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# ICMC         8667
# IOM          1034
# CWS            17
# IRC             4
# [Unknown]       2
# Name: Field:Rsc, dtype: int64
# ----------------------------------------------------------------------------------------------------
# محمد                         33
# احمد                         13
# خالد                          8
# نور                           6
# عمر                           6
#                              ..
# براءة احمد اسماعيل            1
# رهام سعيد محمد الوسمي         1
# راغب داود الحمادي             1
# زينب محمد جواد محمد محمود     1
# حيدر                          1
# Name: Field:Unhcr Case File Family Name 2, Length: 532, dtype: int64
# ----------------------------------------------------------------------------------------------------
# rsc.icmc.net/login         8667
# jordan.iom.int/refinfo/    1021
# mycase.rscafrica.org/        17
# [None]                       13
# casi.rescue.org               4
# [Unknown]                     2
# Name: Field:Rsc Case Status Portal, dtype: int64
# ----------------------------------------------------------------------------------------------------
# info.rsc@icmc.net          8667
# ic@iom.int                 1021
# case@CWSAfrica.org           17
# ICC@iom.int                  12
# RSCInquiries@rescue.org       2
# [Unknown]                     2
# KL.Inquiries@rescue.org       2
# icla@iom.int                  1
# Name: Field:Rsc Contact Email, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Dob, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:City, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# لا أعرف رقم ملفي.    46
# لماذا                 6
# لا اعرف               5
# ليس معي الان          4
# لا اعلم               3
#                      ..
# 245-15c07995          1
# 245-13C03570          1
# 245-13C66784          1
# 947-13C09866          1
# 947-12C05235          1
# Name: Field:Unhcr Number, Length: 2391, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 76059334          2
# 96170671496       2
# 00966533876764    2
# 0096176992798     2
# لا املك رقم       2
#                  ..
# 0096170023220     1
# 0096176687739     1
# 78951928          1
# 96171175010       1
# 0096176927197     1
# Name: Field:Phone Number, Length: 2802, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Whole Name, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# results.unhcr.org.tr/    479
# Name: Field:Unhcr Case Status Portal, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Threat Severity: 5    355
# Threat Severity: 4    147
# Threat Severity: 3    132
# 5                      68
# Threat Severity: 1     54
# Threat Severity: 2     48
# 3                      34
# 4                      19
# 1                      12
# 2                      10
# ٤                       1
# ١                       1
# Name: Field:Aggr 1 Threat Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Attack Severity: 1    169
# Attack Severity: 3    140
# Attack Severity: 5    118
# Attack Severity: 2     81
# Attack Severity: 4     62
# 1                      31
# 5                      27
# 3                      25
# 2                      15
# 4                       9
# ٢                       3
# ٥                       1
# ١                       1
# Name: Field:Aggr 1 Attack Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat: 5    60
# 5                                     11
# Severity of Most Serious Threat: 3    10
# Severity of Most Serious Threat: 4     9
# Severity of Most Serious Threat: 2     7
# Severity of Most Serious Threat: 1     7
# 4                                      4
# 3                                      3
# 2                                      1
# ١                                      1
# Name: Field:Aggr 1 Mst Svr Threat, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Attack: 5    168
# Severity of Most Serious Attack: 1    108
# Severity of Most Serious Attack: 3    103
# Severity of Most Serious Attack: 4     80
# Severity of Most Serious Attack: 2     49
# 5                                      29
# 3                                      22
# 1                                      19
# 4                                      14
# 2                                      11
# ٣                                       1
# ٥                                       1
# ١                                       1
# Name: Field:Aggr 1 Mst Svr Attack, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat if Only Threats: 5    132
# Severity of Most Serious Threat if Only Threats: 3     84
# Severity of Most Serious Threat if Only Threats: 4     69
# Severity of Most Serious Threat if Only Threats: 1     39
# Severity of Most Serious Threat if Only Threats: 2     38
# 5                                                      30
# 1                                                      14
# 3                                                      14
# 4                                                       9
# 2                                                       6
# ٥                                                       1
# Name: Field:Aggr 1 Mst Svr Only Threats, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Threat Severity: 5    379
# Threat Severity: 3    177
# Threat Severity: 4    157
# Threat Severity: 1     84
# Threat Severity: 2     78
# 5                      71
# 3                      47
# 4                      22
# 1                      19
# 2                      11
# ٤                       1
# ١                       1
# Name: Field:Threat Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Attack Severity: 1    154
# Attack Severity: 3    101
# Attack Severity: 5     95
# Attack Severity: 2     70
# Attack Severity: 4     46
# 1                      34
# 5                      20
# 3                      20
# 2                      11
# 4                      10
# ٢                       2
# ١                       1
# Name: Field:Attack Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat: 5    32
# 5                                     10
# Severity of Most Serious Threat: 3     9
# Severity of Most Serious Threat: 4     8
# Severity of Most Serious Threat: 1     6
# Severity of Most Serious Threat: 2     4
# 2                                      2
# 3                                      2
# 4                                      1
# ١                                      1
# Name: Field:Mst Svr Threat, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Attack: 5    123
# Severity of Most Serious Attack: 1     96
# Severity of Most Serious Attack: 3     94
# Severity of Most Serious Attack: 4     65
# Severity of Most Serious Attack: 2     46
# 5                                      25
# 3                                      16
# 1                                      13
# 4                                      12
# 2                                       7
# ٣                                       1
# ١                                       1
# Name: Field:Mst Svr Attack, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat if Only Threats: 5    158
# Severity of Most Serious Threat if Only Threats: 3    103
# Severity of Most Serious Threat if Only Threats: 4     93
# Severity of Most Serious Threat if Only Threats: 1     70
# Severity of Most Serious Threat if Only Threats: 2     50
# 5                                                      33
# 3                                                      26
# 1                                                      18
# 4                                                      12
# 2                                                      11
# ٥                                                       1
# Name: Field:Mst Svr Only Threats, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Attack Severity: 5    46
# Attack Severity: 1    46
# Attack Severity: 3    30
# Attack Severity: 2    17
# Attack Severity: 4    14
# 5                      7
# 1                      6
# 2                      4
# 3                      4
# 4                      4
# Name: Field:Aggr 2 Attack Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Threat Severity: 5    107
# Threat Severity: 3     37
# Threat Severity: 4     35
# Threat Severity: 1     31
# Threat Severity: 2     21
# 5                      19
# 3                      13
# 1                       5
# 4                       5
# 2                       3
# Name: Field:Aggr 2 Threat Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Attack: 5    53
# Severity of Most Serious Attack: 1    34
# Severity of Most Serious Attack: 3    32
# Severity of Most Serious Attack: 4    14
# 5                                     12
# Severity of Most Serious Attack: 2    11
# 3                                      6
# 4                                      4
# 1                                      3
# 2                                      3
# Name: Field:Aggr 2 Mst Svr Attack, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat: 5    6
# Severity of Most Serious Threat: 3    4
# Severity of Most Serious Threat: 1    3
# 5                                     2
# 2                                     1
# Name: Field:Aggr 2 Mst Svr Threat, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat if Only Threats: 5    41
# Severity of Most Serious Threat if Only Threats: 4    22
# Severity of Most Serious Threat if Only Threats: 3    19
# Severity of Most Serious Threat if Only Threats: 1    19
# Severity of Most Serious Threat if Only Threats: 2    15
# 3                                                     11
# 5                                                      6
# 2                                                      4
# 1                                                      3
# 4                                                      1
# Name: Field:Aggr 2 Mst Svr Only Threats, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Attack Severity: 5    11
# Attack Severity: 1     9
# Attack Severity: 3     8
# Attack Severity: 2     5
# Attack Severity: 4     5
# 5                      2
# 3                      1
# 4                      1
# Name: Field:Aggr 3 Attack Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Threat Severity: 5    30
# Threat Severity: 3    15
# Threat Severity: 4     7
# Threat Severity: 1     6
# Threat Severity: 2     5
# 5                      5
# 3                      1
# Name: Field:Aggr 3 Threat Within Last 6 Months, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Attack: 5    20
# Severity of Most Serious Attack: 3    12
# Severity of Most Serious Attack: 1     7
# Severity of Most Serious Attack: 4     7
# Severity of Most Serious Attack: 2     5
# 5                                      3
# 3                                      1
# Name: Field:Aggr 3 Mst Svr Attack, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat: 5    5
# Severity of Most Serious Threat: 4    2
# 5                                     1
# Name: Field:Aggr 3 Mst Svr Threat, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Severity of Most Serious Threat if Only Threats: 5    7
# Severity of Most Serious Threat if Only Threats: 1    6
# Severity of Most Serious Threat if Only Threats: 3    4
# 5                                                     3
# Severity of Most Serious Threat if Only Threats: 4    3
# Severity of Most Serious Threat if Only Threats: 2    1
# Name: Field:Aggr 3 Mst Svr Only Threats, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Test Aggr Num, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Test Fam Num, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Unhcr Case File Family Gender, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# زوجتي      355
# ابني       117
# زوجي        97
# ابنتي       93
# غير ذلك     39
# والدتي      36
# والدي       33
# أخي         26
# أختي        10
# Brother      2
# Husband      2
# Father       1
# Wife         1
# ذلك          1
# Name: Field:Unhcr Case File Family Relation 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# أنثى      354
# ذكر       332
# Female      4
# Name: Field:Unhcr Case File Family Gender 2, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ابني        287
# ابنتي       247
# زوجتي        47
# والدتي       35
# أخي          20
# أختي         16
# زوجي         15
# غير ذلك      14
# والدي         5
# Daughter      2
# Mother        2
# Name: Field:Unhcr Case File Family Relation 2, dtype: int64
# ----------------------------------------------------------------------------------------------------
# محمد                  30
# احمد                   9
# محمود                  6
# علي                    4
# شهد                    4
#                       ..
# زيدزولهمةمحمدالعبد     1
# اسماءنجم الغفن         1
# فاطمة الهلال           1
# غنئ طحان               1
# نبيل                   1
# Name: Field:Unhcr Case File Family Name 3, Length: 443, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ذكر       295
# أنثى      256
# Male        2
# Female      2
# Name: Field:Unhcr Case File Family Gender 3, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ابني        257
# ابنتي       200
# أخي          24
# زوجتي        21
# أختي         20
# غير ذلك      15
# زوجي          5
# والدي         5
# والدتي        4
# Daughter      1
# Brother       1
# Sister        1
# Son           1
# Name: Field:Unhcr Case File Family Relation 3, dtype: int64
# ----------------------------------------------------------------------------------------------------
# محمد                                  16
# احمد                                   6
# ريماس                                  4
# عبدالله                                4
# علي                                    4
#                                       ..
# منى                                    1
# زوجتي و ابنتي لكن ليسو من ضمن مفلي     1
# تالين                                  1
# فرح                                    1
# زهراء                                  1
# Name: Field:Unhcr Case File Family Name 4, Length: 305, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ذكر     201
# أنثى    179
# Male      1
# Name: Field:Unhcr Case File Family Gender 4, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ابني       154
# ابنتي      132
# زوجتي       29
# أخي         23
# زوجي        14
# أختي        10
# غير ذلك      8
# والدتي       7
# والدي        3
# Son          1
# Name: Field:Unhcr Case File Family Relation 4, dtype: int64
# ----------------------------------------------------------------------------------------------------
# محمد              9
# احمد              4
# حلا               4
# اية               3
# علي               3
#                  ..
# لا يوجد           1
# محمد فاضل         1
# احمد حسن حميدو    1
# روان              1
# عبد الملك         1
# Name: Field:Unhcr Case File Family Name 5, Length: 189, dtype: int64
# ----------------------------------------------------------------------------------------------------
# أنثى    114
# ذكر     105
# Name: Field:Unhcr Case File Family Gender 5, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ابني       77
# ابنتي      71
# أختي       15
# زوجتي      15
# أخي        13
# غير ذلك    12
# زوجي       10
# والدتي      5
# والدي       1
# Name: Field:Unhcr Case File Family Relation 5, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Unchr Case File Family Name 6, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Unchr Case File Family Age 6, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Unchr Case File Family Gender 6, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Unchr Case File Family Relation 6, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Medical Condition Severity, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# أنا                        682
# محمد                        26
# زوجتي                       19
# زوجي                        14
# احمد                        11
#                           ...
# خواده بكار                   1
# امونه الحمد العلو            1
# انا محمد ماهر طاطين          1
# سالي فراز الثلجي             1
# احمد الخضر وصبحة الخالد      1
# Name: Field:Medical Condition 1 Afftd Fam Mbr, Length: 679, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ديسك                                                                                                           16
# الربو                                                                                                          12
# مرض السكري                                                                                                     12
# ربو                                                                                                            11
# سكري                                                                                                           11
#                                                                                                                ..
# قصور جارات الدرق                                                                                                1
# زوجتي تعاني من الاعصاب                                                                                          1
# ابني محتاج لمركز تأهيل عمرو ٣سنين ونص وماعم يحكي                                                                1
# أعاني انا من طنين دايم وعدم سمع بأذني يسرى بسبب اصابه على رأس                                                   1
# انا اعاني من وجع في الظهر ولم استطيع ان اذا الى مشفى او طبيب مختص لعدم وجود المال واخشى من وجود دسك في ظهري     1
# Name: Field:Medical Condition 1 Name, Length: 1371, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Medical Condition 1 Pos Prog, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# لا          1211
# نعم          325
# No             4
# لا لا          1
# لا لا لا       1
# Name: Field:Medical Condition 1 Inc Treatment, dtype: int64
# ----------------------------------------------------------------------------------------------------
# نعم             986
# لا أعلم         508
# لا               44
# Yes               3
# I'm not sure      1
# Name: Field:Medical Condition 1 Treatment Abroad, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 5    650
# 3    346
# 4    327
# 2    110
# 1    105
# ٥      3
# ١      1
# Name: Field:Medical Condition 1 Assessment, dtype: int64
# ----------------------------------------------------------------------------------------------------
# محمد                                                                                                                                                                                                                                                                                          2
# سمير                                                                                                                                                                                                                                                                                          2
# احمد                                                                                                                                                                                                                                                                                          1
# محمد احمد كريز زوج ابنة خالت زوجتي                                                                                                                                                                                                                                                            1
# Nadea                                                                                                                                                                                                                                                                                         1
# شهاب                                                                                                                                                                                                                                                                                          1
# همسه السلطاني                                                                                                                                                                                                                                                                                 1
# Joan                                                                                                                                                                                                                                                                                          1
# ربى                                                                                                                                                                                                                                                                                           1
# رنا يوسف /اخت                                                                                                                                                                                                                                                                                 1
# نانسي                                                                                                                                                                                                                                                                                         1
# Heni                                                                                                                                                                                                                                                                                          1
# Misaa                                                                                                                                                                                                                                                                                         1
# اسراء محمد عبدعلي الحداد                                                                                                                                                                                                                                                                      1
# شيماء                                                                                                                                                                                                                                                                                         1
# Salam, Sarmad, Bashar And Wurood                                                                                                                                                                                                                                                              1
# Jennifer                                                                                                                                                                                                                                                                                      1
# سامر                                                                                                                                                                                                                                                                                          1
# أبي                                                                                                                                                                                                                                                                                           1
# محمد رامي زردة                                                                                                                                                                                                                                                                                1
# عمر                                                                                                                                                                                                                                                                                           1
# عايده                                                                                                                                                                                                                                                                                         1
# جمال                                                                                                                                                                                                                                                                                          1
# جواد                                                                                                                                                                                                                                                                                          1
# غادة                                                                                                                                                                                                                                                                                          1
# نور الايوبي                                                                                                                                                                                                                                                                                   1
# انتصار سلمان رجب                                                                                                                                                                                                                                                                              1
# خديجة                                                                                                                                                                                                                                                                                         1
# سيمون                                                                                                                                                                                                                                                                                         1
# ميسه                                                                                                                                                                                                                                                                                          1
# يحيى محمود البريدي                                                                                                                                                                                                                                                                            1
# محمدسلهب                                                                                                                                                                                                                                                                                      1
# مصطفی ابراهیم عزیز  ابي\nرابیعة محمد سعید      امي\nكمال مصطفی ابراهیم  اخي\nجلال مصطفی ابراهیم اخي\nجمال مصطفی ابراهیم اخي\nبیلال مصطفی ابراهیم اخي\nمروان مصطفی ابراهیم اخي\nسیروان مصطفی ابراهیم اخي\nمروة مصطفی ابراهیم    اختي\nعبیر مصطفی ابراهیم    اختي\nودیان مصطفی ابراهیم  اختي    1
# محمد بشير الحلبي                                                                                                                                                                                                                                                                              1
# صباح محمد داود                                                                                                                                                                                                                                                                                1
# Mike                                                                                                                                                                                                                                                                                          1
# Jamil                                                                                                                                                                                                                                                                                         1
# ناصر                                                                                                                                                                                                                                                                                          1
# نديم                                                                                                                                                                                                                                                                                          1
# فاندا                                                                                                                                                                                                                                                                                         1
# Diana                                                                                                                                                                                                                                                                                         1
# Name: Field:I 130 Relative Name 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Married      8273
# Unmarried    1780
# Name: Field:Marital Status, dtype: int64
# ----------------------------------------------------------------------------------------------------
# sister     15
# brother    13
# husband     4
# son         2
# mother      2
# wife        2
# father      1
# Name: Field:I 130 Relative Relation 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# مواطن أمريكي         16
# مواطنة أمريكية       15
# حامل بطاقة خضراء      6
# U S citizen           4
# حاملة بطاقة خضراء     1
# Green card holder     1
# Name: Field:I 130 Relative Legal Status 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 130 Relative Name 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 130 Relative Relation 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 130 Relative Legal Status 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# ذكر       22
# أنثى      16
# Female     3
# Male       2
# Name: Field:I 130 Relative Gender 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 130 Relative Gender 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# سمير          1
# ليفر يازجي    1
# نديم          1
# عمر           1
# سامر          1
# Name: Field:Siv Follow To Join Relative Name 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# husband    3
# wife       1
# Name: Field:Siv Follow To Join Relative Rltn 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Siv Follow To Join Relative Lgl St 1, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# ذكر     4
# أنثى    1
# Name: Field:Siv Follow To Join Relative Gender 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Siv Follow To Join Relative Name 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Siv Follow To Join Relative Rltn 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Siv Follow To Join Relative Lgl St 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Siv Follow To Join Relative Gender 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Name 1, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Relation 1, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Legal Status 1, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Gender 1, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Name 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Relation 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Legal Status 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:I 730 Relative Gender 2, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# سمير                  2
# خديجة                 1
# أبي                   1
# سامر                  1
# هبة                   1
# شيماء                 1
# يامن                  1
# Heni                  1
# Nidal                 1
# ظلال                  1
# طارق سلمان رجب        1
# اختي وفاء بيطار       1
# عمي                   1
# جمال محمد هديهد       1
# Father                1
# عمر                   1
# اياس صالح صالح        1
# سهيل                  1
# Misaa                 1
# منال الفحل            1
# محسن الضماد           1
# نديم                  1
# Mike                  1
# يحيى محمود البريدي    1
# جورج ابني             1
# سامي                  1
# ليفر يازجي            1
# عيشة غنام             1
# Name: Field:Dap Siv Relative Name 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# sister     9
# brother    8
# father     3
# husband    3
# son        2
# wife       1
# Name: Field:Dap Siv Relative Relation 1, dtype: int64
# ----------------------------------------------------------------------------------------------------
# حامل بطاقة خضراء      8
# ...
# 👍                                                                162
# 10                                                               139
# للمساعدة                                                          69
# للاستفادة                                                         62
# مفيد                                                              57
#                                                                 ...
# الدقه                                                              1
# يحتاجون لنصحك                                                      1
# كما شرحت سابقا ليش هناك فائدة طالما لا تستطيعون اعادة التوطين      1
# لانني على يقين بأنكم ستساعدوني                                     1
# لمساعدتهم ولانكم توضحون كل شيئ بطريقة جميلة والثقة طبعا            1
# Name: Field:End Feedback Recommend Open Ended, Length: 6154, dtype: int64
# ----------------------------------------------------------------------------------------------------
# لا                                                                                  1101
# لا شكرا                                                                              193
# شكرا                                                                                 187
# نعم                                                                                  134
# 👍                                                                                    110
#                                                                                     ...
# هل يوجد اي فرصه لترشيح ملفي لاعاده التوطين في اي بلد من بلدان التي تستقبل لاجئين       1
# هل من الممكن أن يتم قبولنه في برنامج أعادت الطوطين                                     1
# سكرا لك روبون                                                                          1
# كيف استطيع ان اقدم للسفر                                                               1
# نرجو ان تكون المراسلة مع موضف وليس مجيب آلي                                            1
# Name: Field:End Feedback Other Information Needs, Length: 5308, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Yes    5200
# No     2211
# Name: Field:End Feedback Follow Up Conversation, dtype: int64
# ----------------------------------------------------------------------------------------------------
# لا اعرف           4
# لماذا             3
# 76059334          2
# 0096170671496     2
# 76348840          2
#                  ..
# 0096171882175     1
# 5734244941        1
# 0096176707221     1
# 00905413760147    1
# 0096176927197     1
# Name: Field:Conversion, Length: 2577, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 1059 SIV    5
# Name: Field:SIV 1059, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Reason Unable to Move: ليس لدي المال                                                                                     3
# Reason Unable to Move: بسبب الحالة المادية                                                                               2
# Reason Unable to Move: لعدم توفر المال                                                                                   2
# Reason Unable to Move: السبب مادي                                                                                        2
# Reason Unable to Move: من اجل المدارس والاهل                                                                             1
#                                                                                                                         ..
# Reason Unable to Move: لاني أسكن ببيت الاجار قليل وليس لي القدرة بمكان غيره بسبب قلة الاموال معنا ولا احد يساعدنا        1
# Reason Unable to Move: بسبب دراسه اولادي                                                                                 1
# Reason Unable to Move: انا حاليا عاطل عن العمل بسبب الاقامة والاوضاع الراهنة في لبنان  وليس لدي المال الكافي للانتقال    1
# Reason Unable to Move: ليس لدي مال                                                                                       1
# Reason Unable to Move: زوجي عمله قريب من هاذا البيت                                                                      1
# Name: Field:Reason Unable to Move, Length: 315, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Moved to Avoid This Aggressor: Unable    652
# Moved to Avoid This Aggressor: Yes       546
# Moved to Avoid This Aggressor: No        106
# Name: Field:Aggr 1 Moved to Avoid Aggr, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Received Threats Since Moving: Yes    365
# Received Threats Since Moving: No     173
# Name: Field:Aggr 1 Threats Since Moving, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Reason Unable to Move: ليس لدي المال                                                                    3
# Reason Unable to Move: نعم                                                                              2
# Reason Unable to Move: الوضع المادي سيئ جدا                                                             2
# Reason Unable to Move: السبب مادي                                                                       2
# Reason Unable to Move: عدم توفر المال                                                                   2
#                                                                                                        ..
# Reason Unable to Move: لانني غيرقادرة على دفع تسديد دين الاجار                                          1
# Reason Unable to Move: لانه ليس لدي الامكانية و الاستطاعه الماديه                                       1
# Reason Unable to Move: لاأملك المال لكي أسكن في منزل                                                    1
# Reason Unable to Move: لأنه من سابع المستحيلات ترجع تنقل كملكك لغير ولاية والنقل يحتاج لمصاريف باهضة    1
# Reason Unable to Move: بسبب الوضع المعيشي والصعوبة في جلب المال                                         1
# Name: Field:Aggr 1 Reason Unable to Move, Length: 354, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Moved to Avoid This Aggressor: Unable    182
# Moved to Avoid This Aggressor: Yes       140
# Moved to Avoid This Aggressor: No         60
# Name: Field:Aggr 2 Moved to Avoid Aggr, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Moved to Avoid This Aggressor: Unable    49
# Moved to Avoid This Aggressor: Yes       38
# Moved to Avoid This Aggressor: No        13
# Name: Field:Aggr 3 Moved to Avoid Aggr, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Received Threats Since Moving: Yes    100
# Received Threats Since Moving: No      39
# Name: Field:Aggr 2 Threats Since Moving, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Received Threats Since Moving: Yes    35
# Received Threats Since Moving: No      3
# Name: Field:Aggr 3 Threats Since Moving, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Reason Unable to Move: ليس لدي مال                                                                                                                    2
# Reason Unable to Move: انا عاطل عن العمل وليس لدي نقود كافية لتغيير مكان سكني                                                                         1
# Reason Unable to Move: اجارات لبيوت غاليه                                                                                                             1
# Reason Unable to Move: ما معي ولا ليرة ويم بدي روح                                                                                                    1
# Reason Unable to Move: زوجي لايعمل واجار هذا البيت  قليل وللاملك ايّ نقود لأستطيع ان انتقل الى بيت جديد وبناتي يدرسون هنا لااستطيع تغير هذا المكان    1
#                                                                                                                                                      ..
# Reason Unable to Move: اسباب ماليه                                                                                                                    1
# Reason Unable to Move: لااملك المال                                                                                                                   1
# Reason Unable to Move: اسباب مادية                                                                                                                    1
# Reason Unable to Move: بسبب اجار البيت                                                                                                                1
# Reason Unable to Move: زوجي عمله قريب من هاذا البيت                                                                                                   1
# Name: Field:Aggr 2 Reason Unable to Move, Length: 78, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Reason Unable to Move: لانني لااملك المال الكافي لتغير سكني ولايوجد اي جهة تساعدني في ذلك                                                                 1
# Reason Unable to Move: بسبب تراكم اجار المنزل 5 أشهر                                                                                                      1
# Reason Unable to Move: صاحب المنزل الو معي اجار ٣ اشهر                                                                                                    1
# Reason Unable to Move: بسبب اجار البيت                                                                                                                    1
# Reason Unable to Move: عدم تنقلي سببه انه بعد المراجعات الى الافرع الامنيه اخبروني باني اذا غيرت سكني يجب ابلاغهم على الفور                               1
# Reason Unable to Move: بسبب دراسه اولادي                                                                                                                  1
# Reason Unable to Move: ولك خلص                                                                                                                            1
# Reason Unable to Move: احوالنا السيئة وصاحب البيت بدو منا اجار بيت                                                                                        1
# Reason Unable to Move: بسبب  رخص  البيت                                                                                                                   1
# Reason Unable to Move: من الماده                                                                                                                          1
# Reason Unable to Move: مامعي مصاري روح اخد بيت هون بيوت غالي ومافي وين بدي روح                                                                            1
# Reason Unable to Move: لانو مافيني دفع اجار بيت اكتر من هيك و ضعي سي كتر                                                                                  1
# Reason Unable to Move: بسبب الوضع المعيشي وعدم امتلاكي المال وبسبب الحواجز الامنية \nوبسبب ان وجودي بكل لبنان خطر وسيتم التعدي علي في كل مكان في لبنان    1
# Reason Unable to Move: الاسئله يتم تكرارها هل هذا طبيعي؟!                                                                                                 1
# Reason Unable to Move: مافيني اطلع من السكن \nوماعندي مكان تاني روح عليه                                                                                  1
# Name: Field:Aggr 3 Reason Unable to Move, dtype: int64
# ----------------------------------------------------------------------------------------------------
# نعم                                                                                                                2
# تحرش                                                                                                               1
# لا                                                                                                                 1
# من اجل دفع مال لم اخذه ولا اعرف عنه شيئ                                                                            1
# تهجومو علي اكثر من 15 شخص                                                                                          1
#                                                                                                                   ..
# بل صراخ والضرب واشعر بأي لحظه سيتم قتلي على يدهم انهم جدا متعصبين لدينهم ويجبروني عليه                             1
# من اولاد يعتدو على بناتي وصاحب البيت عطول تهديد                                                                    1
# خطف وقتل ابنتي                                                                                                     1
# تشليح وسرقه                                                                                                        1
# نحن بسبب كبر عائلتي تعرضنا أكثر من مرة للمشاكل والاضطهاد وأثر على اطفالي ولم نعد نشعر بلااستقراروالامان بحياتنا    1
# Name: Field:Open Ended Other Threats, Length: 61, dtype: int64
# ----------------------------------------------------------------------------------------------------
# RFR Submission    17
# Name: Field:RFR Submission, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Vulnerability Assessed    2544
# Name: Field:Vulnerability Assessed, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 2020-02-28T15:47:00.384334+02:00    1
# 2019-08-04T16:57:25.007684+03:00    1
# 2020-02-28T22:17:37.159698+02:00    1
# 2020-02-29T08:48:18.887940+02:00    1
# 2020-02-28T16:24:34.656426+02:00    1
#                                    ..
# 2020-03-01T23:17:04.142222+02:00    1
# 2020-02-29T14:45:17.668309+02:00    1
# 2020-03-01T09:47:21.789866+02:00    1
# 2020-02-27T16:23:44.414174+02:00    1
# 2020-02-29T15:14:12.465584+02:00    1
# Name: Field:Handoff Timestamp, Length: 2238, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Yes    8205
# Name: Field:Prescreening Complete, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Yes    5507
# Name: Field:Pause Handoffs, dtype: int64
# ----------------------------------------------------------------------------------------------------
# نعم.                                                                    127
# بيروت.                                                                  122
# طرابلس.                                                                 101
# البقاع.                                                                  45
# صيدا.                                                                    42
#                                                                        ...
# صيدا وادي الزينه بجانب جامع ناجي العلي.                                   1
# الجنوب بنت جبيل جانب بنك عوده.                                            1
# بيروت الضاحية الجنوبية حارة حريك بجانب مستشفى بهمن.                       1
# طرابلس / مخيم البداوي / مشفى الهلال / بناء عبدالله ابو السعد طابق ٤.      1
# مقيم بالشويفات.                                                           1
# Name: Field:Lebanon Location, Length: 3975, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Relative Abroad Relationship, dtype: int64)
# ----------------------------------------------------------------------------------------------------
# Yes            1817
# Return User     207
# Name: Field:Referral Complete, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Yes    3260
# Name: Field:Pro Se Guidance Received, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Series([], Name: Field:Fields, dtype: int64)
# ----------------------------------------------------------------------------------------------------
