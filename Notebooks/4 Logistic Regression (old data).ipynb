# %% [markdown]
# ## Cleaned data modelling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from scipy.stats import pearsonr
from sklearn.linear_model import LogisticRegression 
import statsmodels.api as sm
from sklearn.ensemble import RandomForestClassifier
# Out:
# /Users/xiaoxiangma/.local/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv("cleaned_data.csv")
data = data.drop(columns=['Unnamed: 0','Program Eligibilities','Client Location (Country)','Client Nationality'])

# %%
print(data.shape)
data.head()
# Out:
# (7655, 118)
#   Vulnerability Threshold Field:Aggr 3 Threats Since Moving  \
# 0                   Above                                No
# 1                   Below                                No
# 2                   Below                                No
# 3                   Below                                No
# 4                   Above                                No
#
#   Field:RFR Submission Field:US Prior Admission  \
# 0                   No                       No
# 1                   No                       No
# 2                   No                       No
# 3                   No                       No
# 4                   No                       No
#
#   Field:Aggr 3 Moved to Avoid Aggr Field:Family Worked for USG  \
# 0                               No                          No
# 1                               No                          No
# 2                               No                          No
# 3                               No                          No
# 4                               No                          No
#
#   ILI Assistance Provided  Field:RFR Field:Aggr 2 Moved to Avoid Aggr Flags  \
# 0                       No        No                               No    No
# 1                       No        No                               No    No
# 2                       No        No                               No    No
# 3                       No        No                              Yes    No
# 4                       No        No                               No    No
#
#    ... Medical_X_LPPN Field:LPPN Score Screening Decision  \
# 0  ...            NaN              NaN   Cannot Represent
# 1  ...            NaN              NaN                NaN
# 2  ...            NaN              NaN                NaN
# 3  ...            0.0              6.0                NaN
# 4  ...            0.0              0.0   Cannot Represent
#
#   Date of Screening Start     Date of Referral First Referral In IRAP Process  \
# 0     2019-08-12 00:00:00  2019-07-25 00:00:00             No              No
# 1                     NaN  2019-08-03 00:00:00             No             Yes
# 2     2019-11-08 00:00:00  2019-08-08 00:00:00            Yes              No
# 3                     NaN  2019-08-02 00:00:00             No              No
# 4     2019-12-20 00:00:00  2019-08-02 00:00:00             No              No
#
#   process_days process_day_>=1 process_day_>=7
# 0          0.0             0.0             0.0
# 1          NaN             NaN             NaN
# 2          NaN             NaN             NaN
# 3          NaN             NaN             NaN
# 4          0.0             0.0             0.0
#
# [5 rows x 118 columns]

# %%
train_data = data.dropna(subset=['process_days'])

# %% [markdown]
# #### Examine null counts

# %%
null_count = pd.Series.to_frame(train_data.isna().sum())
# null_count.rename(columns={"0": "null_count"})
null_count.columns = ["null_counts"]
null_count["total_counts"] = train_data.shape[0]
null_count["null_percent"] = np.round(null_count["null_counts"] / train_data.shape[0] , 5)
null_count["dtype"] = pd.Series.to_frame(train_data.dtypes)
null_count["sample_value"] = train_data.mode()[:1].T
null_count.sort_values(['null_counts'],ascending = False)[:20]
# Out:
#                                        null_counts  total_counts  \
# Field:Handoff Timestamp                        523           786
# Medical_X_LPPN                                 428           786
# Field:LPPN Score                               428           786
# Field:Current Country                          185           786
# Field:Nationality1                             176           786
# Field:Gender                                   175           786
# Created On                                     170           786
# Language                                       170           786
# process_day_>=1                                  8           786
# Screening Decision                               5           786
# Date of Referral                                 2           786
# Married                                          0           786
# Field:Aggr 1 SVT Rating                          0           786
# Adult                                            0           786
# Field:Aggressor 3 Score                          0           786
# Field:Aggr 2 Mst Svr Attack                      0           786
# Field:Age                                        0           786
# Field:End Feedback Helpfulness Rating            0           786
# Field:End Feedback Recommend Rating              0           786
# Field:Medical Needs Score                        0           786
#
#                                        null_percent    dtype  \
# Field:Handoff Timestamp                     0.66539   object
# Medical_X_LPPN                              0.54453  float64
# Field:LPPN Score                            0.54453  float64
# Field:Current Country                       0.23537   object
# Field:Nationality1                          0.22392   object
# Field:Gender                                0.22265   object
# Created On                                  0.21628   object
# Language                                    0.21628   object
# process_day_>=1                             0.01018  float64
# Screening Decision                          0.00636   object
# Date of Referral                            0.00254   object
# Married                                     0.00000    int64
# Field:Aggr 1 SVT Rating                     0.00000    int64
# Adult                                       0.00000    int64
# Field:Aggressor 3 Score                     0.00000    int64
# Field:Aggr 2 Mst Svr Attack                 0.00000    int64
# Field:Age                                   0.00000    int64
# Field:End Feedback Helpfulness Rating       0.00000    int64
# Field:End Feedback Recommend Rating         0.00000    int64
# Field:Medical Needs Score                   0.00000    int64
#
#                                                            sample_value
# Field:Handoff Timestamp                2020-01-14T13:06:09.200927+02:00
# Medical_X_LPPN                                                        0
# Field:LPPN Score                                                      0
# Field:Current Country                                           Lebanon
# Field:Nationality1                                               Syrian
# Field:Gender                                                       Male
# Created On                                          2019-07-27 23:44:20
# Language                                                            ara
# process_day_>=1                                                       0
# Screening Decision                                     Cannot Represent
# Date of Referral                                    2019-07-25 00:00:00
# Married                                                               1
# Field:Aggr 1 SVT Rating                                               0
# Adult                                                                 1
# Field:Aggressor 3 Score                                               0
# Field:Aggr 2 Mst Svr Attack                                           0
# Field:Age                                                             1
# Field:End Feedback Helpfulness Rating                                 1
# Field:End Feedback Recommend Rating                                   1
# Field:Medical Needs Score                                             1

# %%
train_data.shape
# Out:
# (786, 118)

# %%
train_data = train_data.drop(train_data.columns[train_data.isnull().mean()>0.5], axis=1).dropna()
train_data.shape
# Out:
# (586, 115)

# %%
train_data.replace(dict.fromkeys(['Yes','Eligible','Above'], 1),inplace=True)
train_data.replace(dict.fromkeys(['No','Not Eligible','Below','Not Applicable'], 0),inplace=True)

train_data.head()
# Out:
#     Vulnerability Threshold  Field:Aggr 3 Threats Since Moving  \
# 0                         1                                  0
# 4                         1                                  0
# 5                         1                                  0
# 6                         1                                  0
# 10                        1                                  0
#
#     Field:RFR Submission  Field:US Prior Admission  \
# 0                      0                         0
# 4                      0                         0
# 5                      0                         0
# 6                      0                         0
# 10                     0                         0
#
#     Field:Aggr 3 Moved to Avoid Aggr  Field:Family Worked for USG  \
# 0                                  0                            0
# 4                                  0                            0
# 5                                  0                            0
# 6                                  0                            0
# 10                                 0                            0
#
#     ILI Assistance Provided   Field:RFR  Field:Aggr 2 Moved to Avoid Aggr  \
# 0                          0          0                                 0
# 4                          0          0                                 0
# 5                          1          0                                 0
# 6                          0          0                                 0
# 10                         0          0                                 0
#
#     Flags  ...  Field:Worked for USG  Field:Aggr 1 Mst Svr Only Threats  \
# 0       0  ...                     0                                  0
# 4       0  ...                     0                                  0
# 5       0  ...                     0                                  0
# 6       0  ...                     0                                  0
# 10      0  ...                     0                                  0
#
#     Screening Decision  Date of Screening Start     Date of Referral  \
# 0     Cannot Represent      2019-08-12 00:00:00  2019-07-25 00:00:00
# 4     Cannot Represent      2019-12-20 00:00:00  2019-08-02 00:00:00
# 5     Cannot Represent      2019-07-31 00:00:00  2019-07-26 00:00:00
# 6     Cannot Represent      2019-12-16 00:00:00  2019-08-01 00:00:00
# 10    Cannot Represent      2019-11-14 00:00:00  2019-08-05 00:00:00
#
#     First Referral  In IRAP Process  process_days  process_day_>=1  \
# 0                0                0           0.0              0.0
# 4                0                0           0.0              0.0
# 5                0                0         139.0              1.0
# 6                0                0           0.0              0.0
# 10               0                0           0.0              0.0
#
#     process_day_>=7
# 0               0.0
# 4               0.0
# 5               1.0
# 6               0.0
# 10              0.0
#
# [5 rows x 115 columns]

# %%
for i in train_data.columns:
#     print(i)
    print(train_data[i].value_counts())
# Out:
# 1    521
# 0     65
# Name: Vulnerability Threshold, dtype: int64
# 0    578
# 1      8
# Name: Field:Aggr 3 Threats Since Moving, dtype: int64
# 0    583
# 1      3
# Name: Field:RFR Submission, dtype: int64
# 0    580
# 1      6
# Name: Field:US Prior Admission, dtype: int64
# 0    575
# 1     11
# Name: Field:Aggr 3 Moved to Avoid Aggr, dtype: int64
# 0    582
# 1      4
# Name: Field:Family Worked for USG, dtype: int64
# 0    548
# 1     38
# Name: ILI Assistance Provided , dtype: int64
# 0    580
# 1      6
# Name: Field:RFR, dtype: int64
# 0    543
# 1     43
# Name: Field:Aggr 2 Moved to Avoid Aggr, dtype: int64
# 0    529
# 1     57
# Name: Flags, dtype: int64
# 0    537
# 1     49
# Name: Field:Aggr 1 Threats Since Moving, dtype: int64
# 0    572
# 1     14
# Name: Field:USRAP Access, dtype: int64
# 0    463
# 1    123
# Name: Field:Aggr 1 Moved to Avoid Aggr, dtype: int64
# 0    407
# 1    179
# Name: Field:Multiple Incidents, dtype: int64
# 0    357
# 1    229
# Name: Field:Vulnerability Assessed, dtype: int64
# 0    579
# 1      7
# Name: URN:Telegram, dtype: int64
# 1    332
# 0    254
# Name: Field:Lack of Durable Solutions, dtype: int64
# 1    383
# 0    203
# Name: Field:Women and Girls at Risk, dtype: int64
# 1    484
# 0    102
# Name: Field:SVT, dtype: int64
# 1    484
# 0    102
# Name: Field:LGBT, dtype: int64
# 1    503
# 0     83
# Name: Field:Hired Lawyer, dtype: int64
# 0    509
# 1     77
# Name: Field:Pause Handoffs, dtype: int64
# 0    380
# 1    206
# Name: Field:Prescreening Complete, dtype: int64
# 1    586
# Name: Field:Ongoing USRAP, dtype: int64
# 1    586
# Name: Field:Previous US Resettlement, dtype: int64
# 1    579
# 0      7
# Name: URN:Facebook, dtype: int64
# 0    586
# Name: Field:RFR within deadline, dtype: int64
# 0    576
# 1     10
# Name: Field:Aggr 2 Threats Since Moving, dtype: int64
# 1    305
# 0    281
# Name: Field:End Feedback Follow Up Conversation, dtype: int64
# 0    585
# 1      1
# Name: Field:I 130 IR, dtype: int64
# 0    585
# 1      1
# Name: Field:SIV Follow to Join, dtype: int64
# 0    585
# 1      1
# Name: Field:P 3, dtype: int64
# 0    584
# 1      2
# Name: Field:SIV, dtype: int64
# 0    586
# Name: Field:DAP via EV, dtype: int64
# 0    586
# Name: Field:DAP as Relative of SIV, dtype: int64
# 0    585
# 1      1
# Name: Field:EO Waiver, dtype: int64
# 0    585
# 1      1
# Name: Field:SIV 101a, dtype: int64
# 0    586
# Name: Field:SIV 1059, dtype: int64
# 0    582
# 1      4
# Name: Field:DAP via I 130, dtype: int64
# 0    565
# 1     21
# Name: Field:ICORN CPJ, dtype: int64
# 0    496
# 1     90
# Name: Field:Canadian Private Sponsorship, dtype: int64
# 0    373
# 1    213
# Name: Field:Germany Family Reunification, dtype: int64
# 0    572
# 1     14
# Name: Field:Medical Condition 3 Inc Treatment, dtype: int64
# 0    572
# 1     14
# Name: Field:Medical Condition 3 SVT, dtype: int64
# 0    540
# 1     46
# Name: Field:Medical Condition 3 Treatment Abroad, dtype: int64
# 0    538
# 1     48
# Name: Field:Traumatic Incident 2 Ong Mdl Needs, dtype: int64
# 0    544
# 1     42
# Name: Field:Medical Condition 2 Inc Treatment, dtype: int64
# 0    541
# 1     45
# Name: Field:Medical Condition 2 SVT, dtype: int64
# 0    478
# 1    108
# Name: Field:Medical Condition 2 Treatment Abroad, dtype: int64
# 0    530
# 1     56
# Name: Field:Medical Condition 1 Inc Treatment, dtype: int64
# 0    495
# 1     91
# Name: Field:Medical Condition 1 SVT, dtype: int64
# 0    418
# 1    168
# Name: Field:Medical Condition 1 Treatment Abroad, dtype: int64
# 0    461
# 1    125
# Name: Field:Traumatic Incident 1 Ong Mdl Needs, dtype: int64
# 2019-11-21 00:00:00    27
# 2019-11-26 00:00:00    25
# 2019-11-27 00:00:00    24
# 2019-11-15 00:00:00    24
# 2019-12-02 00:00:00    24
#                        ..
# 2019-10-25 00:00:00     1
# 2019-11-05 00:00:00     1
# 2019-08-26 00:00:00     1
# 2019-08-04 00:00:00     1
# 2019-12-26 00:00:00     1
# Name: Date of Screening Decision, Length: 80, dtype: int64
# 2019-07-27 23:44:20    3
# 2019-07-25 20:41:21    2
# 2019-07-25 17:58:24    2
# 2019-07-31 00:14:33    2
# 2019-07-26 12:09:22    2
#                       ..
# 2019-08-03 21:58:02    1
# 2019-08-05 18:12:31    1
# 2019-07-31 08:53:12    1
# 2019-08-05 16:47:43    1
# 2019-07-31 16:10:32    1
# Name: Created On, Length: 572, dtype: int64
# 0    567
# 1     19
# Name: Field:USRAP Info Rating, dtype: int64
# 0    514
# 1     72
# Name: Field:Aggr 1 Mst Svr Attack, dtype: int64
# 0    467
# 1    119
# Name: Field:Traumatic Incident 2 Assessment, dtype: int64
# 0    479
# 1    107
# Name: Field:Aggr 1 Attack Within Last 6 Months, dtype: int64
# 0    563
# 1     23
# Name: Field:ICORN Info Rating, dtype: int64
# 0    472
# 1    114
# Name: Field:Aggr 1 Threat Within Last 6 Months, dtype: int64
# 0    427
# 1    159
# Name: Field:Medical Condition 2 Assessment, dtype: int64
# 1    379
# 0    207
# Name: Field:Traumatic Incident 1 Assessment, dtype: int64
# 1    460
# 0    126
# Name: Field:Lebanon UNHCR Info Rating, dtype: int64
# 0    354
# 1    232
# Name: Field:German Reunification Info Rating, dtype: int64
# 0    572
# 1     14
# Name: Field:Aggr 1 Mst Svr Threat, dtype: int64
# 0    565
# 1     21
# Name: Field:Aggr 2 Mst Svr Only Threats, dtype: int64
# 0    551
# 1     35
# Name: Field:Aggr 2 Attack Within Last 6 Months, dtype: int64
# 0    548
# 1     38
# Name: Field:Aggr 2 Threat Within Last 6 Months, dtype: int64
# 0    520
# 1     66
# Name: Field:Medical Condition 3 Assessment, dtype: int64
# 0    513
# 1     73
# Name: Field:Aggr 2 SVT Rating, dtype: int64
# 0    570
# 1     16
# Name: Field:Aggr 3 SVT Rating, dtype: int64
# 0    367
# 1    219
# Name: Field:Aggressor 1 Score, dtype: int64
# 0    365
# 1    221
# Name: Field:Aggr 1 SVT Rating, dtype: int64
# 1    484
# 0    102
# Name: Field:Years in Current Country, dtype: int64
# 1    484
# 0    102
# Name: Field:Medical Needs Score, dtype: int64
# 1    558
# 0     28
# Name: Field:End Feedback Recommend Rating, dtype: int64
# 1    579
# 0      7
# Name: Field:End Feedback Helpfulness Rating, dtype: int64
# 1    584
# 0      2
# Name: Field:Age, dtype: int64
# 0    561
# 1     25
# Name: Field:Aggr 2 Mst Svr Attack, dtype: int64
# 1    312
# 0    274
# Name: Field:Aggressor 3 Score, dtype: int64
# 1    585
# 0      1
# Name: Adult, dtype: int64
# 1    498
# 0     88
# Name: Married, dtype: int64
# Lebanon         482
# Turkey           74
# Egypt            21
# Iraq              7
# Saudi Arabia      1
# Syria             1
# Name: Field:Current Country, dtype: int64
# Syrian    578
# Iraqi       8
# Name: Field:Nationality1, dtype: int64
# Male      447
# Female    139
# Name: Field:Gender, dtype: int64
# ara    579
# eng      7
# Name: Language, dtype: int64
# 0    586
# Name: Field:Aggr 3 Reason Unable to Move, dtype: int64
# 0    586
# Name: Field:I130 Info Rating, dtype: int64
# 0    585
# 1      1
# Name: Field:Aggr 3 Mst Svr Threat, dtype: int64
# 0    586
# Name: Field:DAPI130 Info Rating, dtype: int64
# 0    584
# 1      2
# Name: Field:Aggr 2 Mst Svr Threat, dtype: int64
# 0    581
# 1      5
# Name: Field:Aggr 3 Mst Svr Only Threats, dtype: int64
# 0    585
# 1      1
# Name: Field:P3 Info Rating, dtype: int64
# 0    582
# 1      4
# Name: Field:Aggr 3 Mst Svr Attack, dtype: int64
# 0    579
# 1      7
# Name: Field:Aggr 3 Attack Within Last 6 Months, dtype: int64
# 0    579
# 1      7
# Name: Field:Aggr 2 Reason Unable to Move, dtype: int64
# 0    577
# 1      9
# Name: Field:Aggr 3 Threat Within Last 6 Months, dtype: int64
# 0    577
# 1      9
# Name: Field:Women and Girls Severity Assessment, dtype: int64
# 0    584
# 1      2
# Name: Field:DAPEV Info Rating, dtype: int64
# 0    482
# 1    104
# Name: Field:Canadian Sponsorship Info Rating, dtype: int64
# 0    549
# 1     37
# Name: Field:Aggr 1 Reason Unable to Move, dtype: int64
# 0    585
# 1      1
# Name: Field:Nationality2, dtype: int64
# 1    500
# 0     86
# Name: Field:Email Address1, dtype: int64
# 0    582
# 1      4
# Name: Field:I 130 F, dtype: int64
# 0    581
# 1      5
# Name: Field:Worked for USG, dtype: int64
# 0    522
# 1     64
# Name: Field:Aggr 1 Mst Svr Only Threats, dtype: int64
# Cannot Represent    577
# Sent to Intake        9
# Name: Screening Decision, dtype: int64
# 2019-11-21 00:00:00    31
# 2019-11-26 00:00:00    30
# 2019-12-02 00:00:00    30
# 2019-11-28 00:00:00    22
# 2019-12-09 00:00:00    22
#                        ..
# 2019-12-11 00:00:00     1
# 2020-01-03 00:00:00     1
# 2019-11-08 00:00:00     1
# 2019-08-04 00:00:00     1
# 2019-12-26 00:00:00     1
# Name: Date of Screening Start, Length: 68, dtype: int64
# 2019-08-05 00:00:00    106
# 2019-07-31 00:00:00     73
# 2019-07-29 00:00:00     61
# 2019-08-04 00:00:00     43
# 2019-07-25 00:00:00     41
# 2019-07-28 00:00:00     40
# 2019-07-30 00:00:00     40
# 2019-08-06 00:00:00     38
# 2019-08-01 00:00:00     37
# 2019-08-02 00:00:00     31
# 2019-07-26 00:00:00     27
# 2019-08-03 00:00:00     19
# 2019-07-27 00:00:00     13
# 2019-08-07 00:00:00      3
# 2019-07-24 00:00:00      2
# 2019-08-26 00:00:00      1
# 2019-09-10 00:00:00      1
# 2019-09-20 00:00:00      1
# 2019-08-13 00:00:00      1
# 2019-08-08 00:00:00      1
# 2019-09-12 00:00:00      1
# 2019-08-19 00:00:00      1
# 2019-08-31 00:00:00      1
# 2019-08-23 00:00:00      1
# 2019-08-20 00:00:00      1
# 2019-08-11 00:00:00      1
# 2019-08-27 00:00:00      1
# Name: Date of Referral, dtype: int64
# 1    445
# 0    141
# Name: First Referral, dtype: int64
# 0    576
# 1     10
# Name: In IRAP Process, dtype: int64
# 0.0      408
# 1.0       21
# 7.0       20
# 21.0       8
# 8.0        8
# 5.0        7
# 16.0       7
# 2.0        7
# 10.0       6
# 22.0       5
# 14.0       5
# 4.0        5
# 12.0       5
# 11.0       5
# 15.0       5
# 6.0        4
# 26.0       3
# 90.0       3
# 131.0      3
# 28.0       3
# 57.0       2
# 19.0       2
# 23.0       2
# 31.0       2
# 29.0       2
# 13.0       2
# 126.0      2
# 116.0      2
# 17.0       2
# 9.0        1
# 112.0      1
# 46.0       1
# 32.0       1
# 18.0       1
# 49.0       1
# 30.0       1
# 60.0       1
# 38.0       1
# 139.0      1
# 55.0       1
# 54.0       1
# 40.0       1
# 134.0      1
# 62.0       1
# 27.0       1
# 125.0      1
# 20.0       1
# 34.0       1
# 123.0      1
# 130.0      1
# 108.0      1
# 106.0      1
# 147.0      1
# 71.0       1
# 56.0       1
# 104.0      1
# 25.0       1
# 118.0      1
# 70.0       1
# Name: process_days, dtype: int64
# 0.0    408
# 1.0    178
# Name: process_day_>=1, dtype: int64
# 0.0    452
# 1.0    134
# Name: process_day_>=7, dtype: int64

# %%
for col in train_data.columns:
    if len(train_data[col].unique()) == 1:
        train_data.drop(col,inplace=True,axis=1)

# %%
x = pd.Series.to_frame(train_data.dtypes)

# %%
# Convert string to datetime
for i in train_data.columns:
    if (train_data[i].dtype) == "object":
        try:
            train_data[i] = train_data[i].astype('datetime64')
            print("converted: "+i)
        except:
            pass
# Out:
# converted: Date of Screening Decision
# converted: Created On
# converted: Date of Screening Start
# converted: Date of Referral

# %%
# Convert datetime to ordinal
for i in train_data.columns:
    if (train_data[i].dtype) == "datetime64[ns]":
        try:
            train_data[i] = train_data[i].apply(lambda x: x.toordinal())
            print("converted: "+i)
        except:
            pass
# Out:
# converted: Date of Screening Decision
# converted: Created On
# converted: Date of Screening Start
# converted: Date of Referral

# %%
def one_hot(dataframe,column_name):
    gen_onehot_features = pd.get_dummies(dataframe[column_name])
    gen_onehot_features.columns = column_name+"::"+gen_onehot_features.columns
    result = pd.concat([dataframe, gen_onehot_features],axis=1)
    return result

# %%
# One hot categorical
# for i in train_data.columns:
#     if (train_data[i].dtype) == "object":
#         print(i)
#         train_data = one_hot(train_data,i)

# %%
train_data.shape
# Out:
# (586, 106)

# %%
for i in train_data.columns:
    if (train_data[i].dtype) == "object":
        train_data = train_data.drop(columns=[i])

# %% [markdown]
# #### Exclude irap vars

# %%
path = "../Final Soft Launch Results/Current Source Data/"
d1="Data from IRAP 01072020.xlsx"

# %%
irap = pd.read_excel (path+d1)
irap.head()
# Out:
#                               Mona Unique Session ID  \
# 0  ce81140c-7083-4463-90ed-ad36d1a41011.2019-07-2...
# 1  92952aa434524f549543d3fcc79054fe20190804T02434...
# 2  8a4a87a6eeeb43019d820644a8a7534620190802T07350...
# 3  758240c9578a4e29b66bd1d95de9cdc620190802T21293...
# 4  55865e62-97b3-4656-b470-7eaaa6a517cf.2019-07-2...
#
#                     Mona Unique User ID          Created on    Created by  \
# 0  ce81140c-7083-4463-90ed-ad36d1a41011 2019-12-11 06:02:17  Brooke Sauro
# 1  92952aa4-3452-4f54-9543-d3fcc79054fe 2019-12-11 06:02:17  Brooke Sauro
# 2  8a4a87a6-eeeb-4301-9d82-0644a8a75346 2019-12-11 06:02:17  Brooke Sauro
# 3  758240c9-578a-4e29-b66b-d1d95de9cdc6 2019-12-11 06:02:17  Brooke Sauro
# 4  55865e62-97b3-4656-b470-7eaaa6a517cf 2019-12-11 06:02:16  Brooke Sauro
#
#   Pipeline Date of Referral First Referral In IRAP Process  \
# 0     Mona       2019-07-25             No              No
# 1     Mona       2019-08-03             No             Yes
# 2     Mona       2019-08-02             No              No
# 3     Mona       2019-08-02             No              No
# 4     Mona       2019-07-26             No              No
#
#       Screening Stage          Screener  ... Legal Assistance Identified  \
# 0  Screening Complete  Michaela Gallien  ...                         NaN
# 1  Screening Complete    Manal ElKhoury  ...  Vulnerability RST Referral
# 2           Screening        Tiba Fatli  ...  Vulnerability RST Referral
# 3  Screening Complete   Tania El Khoury  ...  Vulnerability RST Referral
# 4  Screening Complete   Tania El Khoury  ...  Vulnerability RST Referral
#
#          ILI Assistance Provided  Mona Case Type Identification  \
# 0                             NaN                      Accurate
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                      Accurate
# 4  Non-Legal Services Information                      Accurate
#
#    Mona Follow up Needed Vulnerability Threshold Screening Decision  \
# 0                     No                   Below   Cannot Represent
# 1                    NaN                     NaN                NaN
# 2                    NaN                     NaN                NaN
# 3                     No                   Below   Cannot Represent
# 4                    Yes                   Below   Cannot Represent
#
#   Date of Screening Decision Flags Client Location (Country)  \
# 0                 2019-08-12   NaN                       NaN
# 1                        NaT   NaN                       NaN
# 2                        NaT   NaN                       NaN
# 3                 2019-12-20   NaN                       NaN
# 4                 2019-12-17   NaN                       NaN
#
#   Client Nationality
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 22 columns]

# %%
for i in irap.columns:
#     print(i)
    if i in train_data.columns:
        print(i)
        train_data = train_data.drop(columns=[i])
# Out:
# Date of Referral
# First Referral
# In IRAP Process
# Date of Screening Start
# ILI Assistance Provided
# Vulnerability Threshold
# Date of Screening Decision
# Flags

# %% [markdown]
# ### Ready for training

# %%
x = train_data.drop(columns=['process_day_>=1','process_day_>=7','process_days'])
# x.head()

# %%
y = train_data["process_day_>=1"]
# y.head()

# %%
clf = LogisticRegression().fit(x,y)

# %%
sorted(list(zip(clf.coef_[0],x.columns)), key=lambda a: abs(a[0]), reverse=True)
# sorted(pearson_time, key=lambda a: abs(a[0]), reverse=True)
# Out:
# [(-1.1250735636699647e-06, 'Created On'),
#  (-2.083589744313222e-12, 'Field:Vulnerability Assessed'),
#  (-2.0714794962720247e-12, 'Field:Lebanon UNHCR Info Rating'),
#  (-1.838695935886761e-12, 'Field:Lack of Durable Solutions'),
#  (-1.680294053237323e-12, 'Married'),
#  (-1.5862310200783196e-12, 'URN:Facebook'),
#  (-1.5560305880602274e-12, 'Field:Age'),
#  (-1.4964178445536312e-12, 'Field:End Feedback Helpfulness Rating'),
#  (-1.496103284900824e-12, 'Adult'),
#  (-1.4767708819396343e-12, 'Field:Women and Girls at Risk'),
#  (-1.3178951397864489e-12, 'Field:End Feedback Recommend Rating'),
#  (1.29670467783197e-12, 'Field:Multiple Incidents'),
#  (1.232209584831951e-12, 'Field:Medical Condition 1 SVT'),
#  (1.2090956506835893e-12, 'Field:Aggr 1 SVT Rating'),
#  (1.1790535348450361e-12, 'Field:Aggressor 1 Score'),
#  (-1.1720949476084227e-12, 'Field:SVT'),
#  (-1.1720949476084227e-12, 'Field:LGBT'),
#  (-1.1720949476084227e-12, 'Field:Years in Current Country'),
#  (-1.1720949476084227e-12, 'Field:Medical Needs Score'),
#  (-1.1267993583466801e-12, 'Field:Prescreening Complete'),
#  (1.1096792014337289e-12, 'Field:Aggr 2 Threat Within Last 6 Months'),
#  (9.91713779840663e-13, 'Field:Aggr 1 Mst Svr Attack'),
#  (-9.317526459025916e-13, 'Field:Email Address1'),
#  (8.720164884787451e-13, 'Field:Aggr 2 SVT Rating'),
#  (-8.417830863810716e-13, 'Field:Hired Lawyer'),
#  (7.273150945786779e-13, 'Field:Medical Condition 1 Treatment Abroad'),
#  (7.268420606480858e-13, 'Field:Medical Condition 2 Assessment'),
#  (7.244815458407846e-13, 'Field:Aggr 1 Threat Within Last 6 Months'),
#  (-6.831030745047142e-13, 'Field:Canadian Sponsorship Info Rating'),
#  (6.651824485857582e-13, 'Field:Traumatic Incident 1 Ong Mdl Needs'),
#  (6.000602211733151e-13, 'Field:Aggr 2 Mst Svr Attack'),
#  (-5.947073671852887e-13, 'Field:Pause Handoffs'),
#  (5.412348780307562e-13, 'Field:Medical Condition 2 SVT'),
#  (-5.341504177451588e-13, 'Field:Canadian Private Sponsorship'),
#  (4.846141048428049e-13, 'Field:Aggr 1 Attack Within Last 6 Months'),
#  (4.547290404796374e-13, 'Field:Medical Condition 2 Treatment Abroad'),
#  (4.501638151933296e-13, 'Field:Aggr 2 Mst Svr Only Threats'),
#  (-3.6929567079960874e-13, 'Field:Traumatic Incident 1 Assessment'),
#  (-3.4807064033251735e-13, 'Field:Germany Family Reunification'),
#  (3.296792464264599e-13, 'Field:Aggr 2 Reason Unable to Move'),
#  (2.6990932848706123e-13, 'Field:Women and Girls Severity Assessment'),
#  (2.6975160952376736e-13, 'Field:RFR'),
#  (2.4049580499028525e-13, 'Field:USRAP Info Rating'),
#  (2.400244749090904e-13, 'Field:Aggr 2 Threats Since Moving'),
#  (-2.376627129549838e-13, 'Field:Aggr 2 Attack Within Last 6 Months'),
#  (2.1029697142022186e-13, 'Field:Medical Condition 3 Inc Treatment'),
#  (2.1029658497943257e-13, 'Field:USRAP Access'),
#  (-1.9738657050988375e-13, 'Field:German Reunification Info Rating'),
#  (1.7978190947846577e-13, 'Field:RFR Submission'),
#  (-1.771051487354021e-13, 'Field:Traumatic Incident 2 Ong Mdl Needs'),
#  (1.51945101342658e-13, 'Field:Aggr 2 Moved to Avoid Aggr'),
#  (1.5052671973626785e-13, 'Field:Aggr 3 SVT Rating'),
#  (1.4989802199394701e-13, 'Field:DAP via I 130'),
#  (1.4989802199394701e-13, 'Field:I 130 F'),
#  (1.4989717885905192e-13, 'Field:Family Worked for USG'),
#  (-1.3367849145297347e-13, 'Field:End Feedback Follow Up Conversation'),
#  (1.2268862932289225e-13, 'Field:Medical Condition 1 Inc Treatment'),
#  (1.2048451607103525e-13, 'Field:Aggr 1 Mst Svr Threat'),
#  (1.2001286980141507e-13, 'Field:Worked for USG'),
#  (1.1985467658092376e-13, 'Field:DAPEV Info Rating'),
#  (1.1985460631906228e-13, 'Field:Aggr 2 Mst Svr Threat'),
#  (-1.178061393068972e-13, 'Field:Aggr 1 Reason Unable to Move'),
#  (-1.1639084921762387e-13, 'Field:Aggr 1 Mst Svr Only Threats'),
#  (9.327577331467447e-14, 'Field:Medical Condition 3 Assessment'),
#  (9.201614703137575e-14, 'Field:Medical Condition 2 Inc Treatment'),
#  (9.028457587644376e-14, 'Field:Aggr 3 Threat Within Last 6 Months'),
#  (-8.949645534040013e-14, 'Field:US Prior Admission'),
#  (-8.335277570626046e-14, 'Field:Aggr 1 Moved to Avoid Aggr'),
#  (-7.343884186241769e-14, 'Field:Aggressor 3 Score'),
#  (6.024279377270353e-14, 'URN:Telegram'),
#  (6.024214385982407e-14, 'Field:Aggr 3 Attack Within Last 6 Months'),
#  (6.008470594408542e-14, 'Field:Aggr 3 Mst Svr Attack'),
#  (5.992777742367588e-14, 'Field:I 130 IR'),
#  (5.992777742367588e-14, 'Field:EO Waiver'),
#  (5.992744368310206e-14, 'Field:Aggr 3 Mst Svr Threat'),
#  (5.992740855212222e-14, 'Field:Nationality2'),
#  (-5.362934739769537e-14, 'Field:Traumatic Incident 2 Assessment'),
#  (3.114400559329705e-14, 'Field:ICORN Info Rating'),
#  (3.067167428122677e-14, 'Field:Medical Condition 3 SVT'),
#  (3.051479845964728e-14, 'Field:Aggr 3 Moved to Avoid Aggr'),
#  (3.035736054412023e-14, 'Field:Aggr 3 Threats Since Moving'),
#  (3.0199869932358344e-14, 'Field:Aggr 3 Mst Svr Only Threats'),
#  (3.004313462558866e-14, 'Field:SIV'),
#  (-2.9885064362969384e-14, 'Field:SIV 101a'),
#  (-2.988506436294905e-14, 'Field:P 3'),
#  (-2.988506436294905e-14, 'Field:P3 Info Rating'),
#  (-2.988487114307937e-14, 'Field:SIV Follow to Join'),
#  (-2.7523407801536437e-14, 'Field:Medical Condition 3 Treatment Abroad'),
#  (-2.7364687609032866e-14, 'Field:Aggr 1 Threats Since Moving'),
#  (1.101661404129722e-15, 'Field:ICORN CPJ')]

# %%
from sklearn.feature_selection import f_classif, chi2, mutual_info_classif, SelectKBest

# %%
def get_feat(method, k, x, y):
    select = SelectKBest(method, k)
    _ = select.fit_transform(x, y)
    return [x.columns[i] for i, val in enumerate(select.get_support()) if val]

# %%
num_features = 10
chi2_select = get_feat(chi2, num_features, x, y)
f_select = get_feat(f_classif, num_features, x, y)
# mutual_select = get_feat(mutual_info_classif, num_features, x, y)

# %%
for i in [chi2_select,f_select]:
    process_day7=sm.Logit(y,x[i]).fit(method="bfgs",maxiter=1000)
    print(process_day7.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.661352
#          Iterations: 73
#          Function evaluations: 74
#          Gradient evaluations: 74
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        process_day_>=1   No. Observations:                  586
# Model:                          Logit   Df Residuals:                      576
# Method:                           MLE   Df Model:                            9
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                -0.07710
# Time:                        11:57:27   Log-Likelihood:                -387.55
# converged:                       True   LL-Null:                       -359.81
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Field:RFR                                    1.7480      1.104      1.583      0.113      -0.416       3.912
# Field:Multiple Incidents                     0.2446      0.311      0.787      0.431      -0.365       0.854
# Field:Medical Condition 1 SVT                0.1366      0.242      0.565      0.572      -0.338       0.611
# Field:Aggr 1 Mst Svr Attack                  0.3768      0.323      1.167      0.243      -0.256       1.010
# Field:Aggr 2 Threat Within Last 6 Months     1.7843      0.566      3.153      0.002       0.675       2.894
# Field:Aggr 2 SVT Rating                     -1.2874      0.496     -2.597      0.009      -2.259      -0.316
# Field:Aggressor 1 Score                     -0.4908      1.028     -0.477      0.633      -2.506       1.524
# Field:Aggr 1 SVT Rating                     -0.3562      1.047     -0.340      0.734      -2.407       1.695
# Field:Aggr 2 Mst Svr Attack                  0.5790      0.598      0.968      0.333      -0.593       1.751
# Field:Aggr 2 Reason Unable to Move           2.6475      1.215      2.180      0.029       0.267       5.028
# ============================================================================================================
# Optimization terminated successfully.
#          Current function value: 0.611463
#          Iterations: 79
#          Function evaluations: 80
#          Gradient evaluations: 80
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        process_day_>=1   No. Observations:                  586
# Model:                          Logit   Df Residuals:                      576
# Method:                           MLE   Df Model:                            9
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                0.004151
# Time:                        11:57:27   Log-Likelihood:                -358.32
# converged:                       True   LL-Null:                       -359.81
# Covariance Type:            nonrobust   LLR p-value:                    0.9648
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Field:Multiple Incidents                     0.4349      0.323      1.346      0.178      -0.199       1.068
# Field:Vulnerability Assessed                -1.2600      0.173     -7.267      0.000      -1.600      -0.920
# Field:Medical Condition 1 SVT                0.3001      0.252      1.191      0.234      -0.194       0.794
# Field:Aggr 1 Mst Svr Attack                  0.3659      0.335      1.093      0.275      -0.290       1.022
# Field:Aggr 2 Threat Within Last 6 Months     1.7890      0.580      3.084      0.002       0.652       2.926
# Field:Aggr 2 SVT Rating                     -1.1386      0.505     -2.255      0.024      -2.128      -0.149
# Field:Aggressor 1 Score                     -0.2013      1.126     -0.179      0.858      -2.408       2.005
# Field:Aggr 1 SVT Rating                     -0.3781      1.145     -0.330      0.741      -2.622       1.865
# Field:Aggr 2 Mst Svr Attack                  0.1983      0.615      0.322      0.747      -1.008       1.404
# Field:Aggr 2 Reason Unable to Move           3.0619      1.227      2.495      0.013       0.657       5.467
# ============================================================================================================

# %% [markdown]
# ### Variables that affect process time

# %% [markdown]
# Field:Aggr 2 Threat Within Last 6 Months - We changed this to a null/not null due to high % of missing data, so person who undergoes threat is more likely to result in >1 day to process.

# %% [markdown]
# Field:Aggr 2 SVT Rating - We changed this to a null/not null due to high % of missing data, so person with a rating is less likely to result in >1 day to process.

# %% [markdown]
# Field:Aggr 2 Reason Unable to Move - same as above, if there is a reason unable to move, more likely to result in >1 day to process.

# %% [markdown]
# Field:Medical Condition 1 SVT - (Awaiting data re-cleanup)Yes --> morelikely to result in >1 day to process.

# %% [markdown]
# Field:Medical Condition 1 Score - If not null, less likely to result in >1 day to process.

# %%
import pprint

# %%
for i in [chi2_select,f_select]:
    model = RandomForestClassifier(max_depth=10,n_estimators = 64,criterion='gini')
    model.fit(x[i],y)
    pprint.pprint(sorted(list(zip(model.feature_importances_,x[i].columns)), reverse=True))
# Out:
# [(0.16585998231982022, 'Field:Aggr 2 Threat Within Last 6 Months'),
#  (0.15516676989829184, 'Field:Medical Condition 1 SVT'),
#  (0.12422139518423793, 'Field:Multiple Incidents'),
#  (0.11244883987767426, 'Field:Aggr 1 Mst Svr Attack'),
#  (0.08985562576155245, 'Field:RFR'),
#  (0.08914926117223523, 'Field:Aggr 2 SVT Rating'),
#  (0.07141107418227248, 'Field:Aggr 2 Mst Svr Attack'),
#  (0.0666551725415878, 'Field:Aggr 1 SVT Rating'),
#  (0.06606748510400845, 'Field:Aggressor 1 Score'),
#  (0.05916439395831921, 'Field:Aggr 2 Reason Unable to Move')]
# [(0.1592031320708434, 'Field:Vulnerability Assessed'),
#  (0.15440191194523958, 'Field:Medical Condition 1 SVT'),
#  (0.13606631970343602, 'Field:Aggr 2 Threat Within Last 6 Months'),
#  (0.11912132597542344, 'Field:Multiple Incidents'),
#  (0.11140865229961018, 'Field:Aggr 1 Mst Svr Attack'),
#  (0.0801737793590168, 'Field:Aggr 2 SVT Rating'),
#  (0.07124662283342778, 'Field:Aggressor 1 Score'),
#  (0.05775504953935922, 'Field:Aggr 2 Mst Svr Attack'),
#  (0.055619780508820854, 'Field:Aggr 1 SVT Rating'),
#  (0.055003425764822714, 'Field:Aggr 2 Reason Unable to Move')]

# %% [markdown]
# ### Irap new data format investigation

# %%
Podio = pd.read_excel('../June data source/20200430 Podio ILI.xlsx')
Zendesk = pd.read_excel('../June data source/20200511 Zendesk ILI.xlsx')

# %%
Podio.head()
# Out:
#                               Mona Unique Session ID  \
# 0  7c7e1b0ccbf84198b2e4679d9f0a009b20200301T16562...
# 1  cf2566dc260245dd802e0ddece04e93b20200229T01101...
# 2  39320c36ec174a27bb2e037659d2fd7520200229T13181...
# 3  96b29a4d34724a5a9cd4dffd5b3b732320200229T14210...
# 4  18e04d06b6d4452f9b70010e8572b73b20200228T20434...
#
#                     Mona Unique User ID          Created on    Created by  \
# 0  7c7e1b0c-cbf8-4198-b2e4-679d9f0a009b 2020-03-04 14:56:02  Brooke Sauro
# 1  cf2566dc-2602-45dd-802e-0ddece04e93b 2020-03-04 14:56:01  Brooke Sauro
# 2  39320c36-ec17-4a27-bb2e-037659d2fd75 2020-03-04 14:56:00  Brooke Sauro
# 3  96b29a4d-3472-4a5a-9cd4-dffd5b3b7323 2020-03-04 14:56:00  Brooke Sauro
# 4  18e04d06-b6d4-452f-9b70-010e8572b73b 2020-03-04 14:55:58  Brooke Sauro
#
#   Pipeline Date of Referral First Referral In IRAP Process  \
# 0     Mona       2020-03-01             No             Yes
# 1     Mona       2020-02-29             No             Yes
# 2     Mona       2020-02-29             No             Yes
# 3     Mona       2020-02-29             No             Yes
# 4     Mona       2020-02-28             No             Yes
#
#       Screening Stage Screener  ... Legal Assistance Identified  \
# 0  Screening Complete      NaN  ...  Vulnerability RST Referral
# 1  Screening Complete      NaN  ...  Vulnerability RST Referral
# 2  Screening Complete      NaN  ...  Vulnerability RST Referral
# 3  Screening Complete      NaN  ...  Vulnerability RST Referral
# 4  Screening Complete      NaN  ...  Vulnerability RST Referral
#
#   ILI Assistance Provided  Mona Case Type Identification  \
# 0          Pro Se Guidance                           NaN
# 1          Pro Se Guidance                           NaN
# 2          Pro Se Guidance                           NaN
# 3          Pro Se Guidance                           NaN
# 4          Pro Se Guidance                           NaN
#
#    Mona Follow up Needed Vulnerability Threshold Screening Decision  \
# 0                    NaN                     NaN                NaN
# 1                    NaN                     NaN                NaN
# 2                    NaN                     NaN                NaN
# 3                    NaN                     NaN                NaN
# 4                    NaN                     NaN                NaN
#
#   Date of Screening Decision Flags Client Location (Country)  \
# 0                        NaT   NaN                       NaN
# 1                        NaT   NaN                       NaN
# 2                        NaT   NaN                       NaN
# 3                        NaT   NaN                       NaN
# 4                        NaT   NaN                       NaN
#
#   Client Nationality
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 22 columns]

# %%
Zendesk.head()
# Out:
#                               Mona Unique Session ID Pipeline  \
# 0  851faec9d8aa4fe2a471eb7fc9ce247e20191014T02543...     Mona
# 1  ac26ef48d78446099e2324d6ed46112b20191012T01264...     Mona
# 2  b735446fbc7f49b2b61f1e63da1a757520191012T00365...     Mona
# 3  7e737b5994fc4addb2b5a1cb70b718cf20191006T23304...     Mona
# 4  70178665bc234831a6156cc7b809d39920191004T13314...     Mona
#
#    Date of Referral First Referral In IRAP Process     Screening Stage  \
# 0  2019-10-26 22:34            Yes              No  Screening Complete
# 1  2019-10-26 22:35            Yes              No  Screening Complete
# 2  2019-10-26 22:35             No              No  Screening Complete
# 3  2019-10-26 22:37             No              No  Screening Complete
# 4  2019-10-26 22:37             No              No  Screening Complete
#
#           Screener Date of Screening Start Program Eligibilities  \
# 0       Tiba Fatli        2020-01-27 15:23               Unknown
# 1       Tiba Fatli        2020-01-28 10:07    Follow-to-Join SIV
# 2  Manal El Khoury        2020-01-28 06:19         Vulnerability
# 3  Manal El Khoury        2020-01-28 06:01         Vulnerability
# 4  Manal El Khoury        2020-01-28 05:46                 USRAP
#
#   ILI Assistance Provided  ... Screening Decision Date of Screening Decision  \
# 0                     NaN  ...   Cannot Represent           2020-03-31 14:22
# 1                     NaN  ...   Cannot Represent           2020-03-24 13:03
# 2                     NaN  ...   Cannot Represent           2020-03-27 03:43
# 3                     NaN  ...   Cannot Represent           2020-03-31 10:48
# 4                     NaN  ...   Cannot Represent           2020-03-30 04:26
#
#           Flags Client Location (Country) Client Nationality Replies  \
# 0  Unresponsive                   Unknown             Syrian       3
# 1  Unresponsive                   Lebanon             Syrian       3
# 2  Unresponsive                   Lebanon             Syrian       3
# 3           NaN                 Palestine        Palestinian       5
# 4  Unresponsive                   Lebanon             Syrian       5
#
#   First reply time in minutes  First resolution time in minutes  \
# 0                    133549.0                            225587
# 1                    134673.0                            215428
# 2                    134445.0                            219188
# 3                    134424.0                            223546
# 4                    134408.0                            223549
#
#    Agent wait time in minutes  Requester wait time in minutes
# 0                       92038                          133549
# 1                       80756                          134673
# 2                       84744                          134445
# 3                       89344                          135993
# 4                       89140                          134408
#
# [5 rows x 22 columns]

# %%
for i in Podio.columns:
    if i in Zendesk.columns:
        print("[Both]:" + i)
    else:
        print("[Only Podio]:" + i)

for i in Zendesk.columns:
    if i not in Podio.columns:
        print("[Only Zendesk]:" + i)
# Out:
# [Both]:Mona Unique Session ID
# [Only Podio]:Mona Unique User ID
# [Only Podio]:Created on
# [Only Podio]:Created by
# [Both]:Pipeline
# [Both]:Date of Referral
# [Both]:First Referral
# [Both]:In IRAP Process
# [Both]:Screening Stage
# [Both]:Screener
# [Both]:Date of Screening Start
# [Both]:Program Eligibilities
# [Only Podio]:Legal Assistance Identified
# [Only Podio]:ILI Assistance Provided
# [Both]:Mona Case Type Identification
# [Only Podio]: Mona Follow up Needed
# [Both]:Vulnerability Threshold
# [Both]:Screening Decision
# [Both]:Date of Screening Decision
# [Both]:Flags
# [Both]:Client Location (Country)
# [Both]:Client Nationality
# [Only Zendesk]:ILI Assistance Provided
# [Only Zendesk]:Replies
# [Only Zendesk]:First reply time in minutes
# [Only Zendesk]:First resolution time in minutes
# [Only Zendesk]:Agent wait time in minutes
# [Only Zendesk]:Requester wait time in minutes
