# %% [markdown]
# ## Marhub data cleaning
# Merged data from mona and irap

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from scipy.stats import pearsonr
from sklearn.linear_model import LogisticRegression 
import statsmodels.api as sm

# %% [markdown]
# #### Reading data

# %%
path = "../Final Soft Launch Results/Current Source Data/"

# %%
d1="Data from IRAP 01072020.xlsx"
d2="Merge for Vulnerability Screening.xlsx"
d3="Raw Data from Mona 01172020.xlsx"

# %%
irap = pd.read_excel (path+d1)
mona = pd.read_excel (path+d3)

# %%
irap.head()
# Out:
#                               Mona Unique Session ID  \
# 0  ce81140c-7083-4463-90ed-ad36d1a41011.2019-07-2...
# 1  92952aa434524f549543d3fcc79054fe20190804T02434...
# 2  8a4a87a6eeeb43019d820644a8a7534620190802T07350...
# 3  758240c9578a4e29b66bd1d95de9cdc620190802T21293...
# 4  55865e62-97b3-4656-b470-7eaaa6a517cf.2019-07-2...
#
#                     Mona Unique User ID          Created on    Created by  \
# 0  ce81140c-7083-4463-90ed-ad36d1a41011 2019-12-11 06:02:17  Brooke Sauro
# 1  92952aa4-3452-4f54-9543-d3fcc79054fe 2019-12-11 06:02:17  Brooke Sauro
# 2  8a4a87a6-eeeb-4301-9d82-0644a8a75346 2019-12-11 06:02:17  Brooke Sauro
# 3  758240c9-578a-4e29-b66b-d1d95de9cdc6 2019-12-11 06:02:17  Brooke Sauro
# 4  55865e62-97b3-4656-b470-7eaaa6a517cf 2019-12-11 06:02:16  Brooke Sauro
#
#   Pipeline Date of Referral First Referral In IRAP Process  \
# 0     Mona       2019-07-25             No              No
# 1     Mona       2019-08-03             No             Yes
# 2     Mona       2019-08-02             No              No
# 3     Mona       2019-08-02             No              No
# 4     Mona       2019-07-26             No              No
#
#       Screening Stage          Screener  ... Legal Assistance Identified  \
# 0  Screening Complete  Michaela Gallien  ...                         NaN
# 1  Screening Complete    Manal ElKhoury  ...  Vulnerability RST Referral
# 2           Screening        Tiba Fatli  ...  Vulnerability RST Referral
# 3  Screening Complete   Tania El Khoury  ...  Vulnerability RST Referral
# 4  Screening Complete   Tania El Khoury  ...  Vulnerability RST Referral
#
#          ILI Assistance Provided  Mona Case Type Identification  \
# 0                             NaN                      Accurate
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                      Accurate
# 4  Non-Legal Services Information                      Accurate
#
#    Mona Follow up Needed Vulnerability Threshold Screening Decision  \
# 0                     No                   Below   Cannot Represent
# 1                    NaN                     NaN                NaN
# 2                    NaN                     NaN                NaN
# 3                     No                   Below   Cannot Represent
# 4                    Yes                   Below   Cannot Represent
#
#   Date of Screening Decision Flags Client Location (Country)  \
# 0                 2019-08-12   NaN                       NaN
# 1                        NaT   NaN                       NaN
# 2                        NaT   NaN                       NaN
# 3                 2019-12-20   NaN                       NaN
# 4                 2019-12-17   NaN                       NaN
#
#   Client Nationality
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# #### generate variables and merge datasets

# %%
irap['process_days'] = irap['Date of Screening Decision']-irap['Date of Screening Start']
irap['process_days'] = irap['process_days'].astype('timedelta64[D]')
# irap['process_daysA'] = irap['Date of Screening Start']-irap['Date of Referral']
# irap['process_daysA'] = irap['process_daysA'].astype('timedelta64[D]')
# irap['process_daysC'] = irap['Date of Screening Decision']-irap['Date of Referral']
# irap['process_daysC'] = irap['process_daysC'].astype('timedelta64[D]')

# %%
mona = mona.rename({'Contact UUID': 'Mona Unique User ID'}, axis=1)

# %%
full = pd.merge(irap, mona, on='Mona Unique User ID',how="outer").dropna(axis=1, how='all')

# %%
full.shape
# Out:
# (7676, 337)

# %%
# full['Field:Gender'].replace(('Male', 'Female'), (1, 0), inplace=True)
# full['Vulnerability Threshold'].replace(('Above', 'Below'), (1, 0), inplace=True)

# %%
def one_hot(dataframe,column_name):
    gen_onehot_features = pd.get_dummies(dataframe[column_name])
    result = pd.concat([dataframe, gen_onehot_features],axis=1)
    return result

# %%
# full['Field:Nationality1'] = 'nationality_' + full['Field:Nationality1']
# full = one_hot(full,'Field:Nationality1')

# %%
# full['Field:Current Country'] = 'curr_country_' + full['Field:Current Country']
# full = one_hot(full,'Field:Current Country')

# %%
full.shape
# Out:
# (7676, 337)

# %%
# numeric = full.select_dtypes(exclude=['object','datetime64[ns]'])

# %%
full.head()
# Out:
#                               Mona Unique Session ID  \
# 0  ce81140c-7083-4463-90ed-ad36d1a41011.2019-07-2...
# 1  92952aa434524f549543d3fcc79054fe20190804T02434...
# 2  92952aa434524f549543d3fcc79054fe20190806T11414...
# 3  8a4a87a6eeeb43019d820644a8a7534620190802T07350...
# 4  758240c9578a4e29b66bd1d95de9cdc620190802T21293...
#
#                     Mona Unique User ID          Created on    Created by  \
# 0  ce81140c-7083-4463-90ed-ad36d1a41011 2019-12-11 06:02:17  Brooke Sauro
# 1  92952aa4-3452-4f54-9543-d3fcc79054fe 2019-12-11 06:02:17  Brooke Sauro
# 2  92952aa4-3452-4f54-9543-d3fcc79054fe 2019-10-07 08:21:12  Brooke Sauro
# 3  8a4a87a6-eeeb-4301-9d82-0644a8a75346 2019-12-11 06:02:17  Brooke Sauro
# 4  758240c9-578a-4e29-b66b-d1d95de9cdc6 2019-12-11 06:02:17  Brooke Sauro
#
#   Pipeline Date of Referral First Referral In IRAP Process  \
# 0     Mona       2019-07-25             No              No
# 1     Mona       2019-08-03             No             Yes
# 2     Mona       2019-08-08            Yes              No
# 3     Mona       2019-08-02             No              No
# 4     Mona       2019-08-02             No              No
#
#       Screening Stage          Screener  ...  \
# 0  Screening Complete  Michaela Gallien  ...
# 1  Screening Complete    Manal ElKhoury  ...
# 2           Screening    Manal ElKhoury  ...
# 3           Screening        Tiba Fatli  ...
# 4  Screening Complete   Tania El Khoury  ...
#
#   Field:Aggr 3 Threats Since Moving Field:Aggr 2 Reason Unable to Move  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   Field:Aggr 3 Reason Unable to Move Field:Open Ended Other Threats  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   Field:RFR Submission Field:Vulnerability Assessed  \
# 0                  NaN                          NaN
# 1                  NaN       Vulnerability Assessed
# 2                  NaN       Vulnerability Assessed
# 3                  NaN                          NaN
# 4                  NaN       Vulnerability Assessed
#
#             Field:Handoff Timestamp Field:Prescreening Complete  \
# 0                               NaN                         Yes
# 1  2019-08-08T00:08:27.754958+03:00                         Yes
# 2  2019-08-08T00:08:27.754958+03:00                         Yes
# 3                               NaN                         NaN
# 4  2019-08-02T22:03:58.358208+03:00                         NaN
#
#   Field:Pause Handoffs Field:Lebanon Location
# 0                  NaN                    NaN
# 1                  Yes                    NaN
# 2                  Yes                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
# [5 rows x 337 columns]

# %%
def label_process_day_1(row):
    if row['process_days'] >= 1 :
        return 1
    if row['process_days'] == 0 :
        return 0
    else: return np.nan
def label_process_day_7(row):
    if row['process_days'] >= 7 :
        return 1
    if row['process_days'] <7 :
        return 0
    else: return np.nan
# def label_process_dayA_1(row):
#     if row['process_daysA'] >= 1 :
#         return 1
#     if row['process_daysA'] == 0 :
#         return 0
#     else: return np.nan
# def label_process_dayC_1(row):
#     if row['process_daysC'] >= 1 :
#         return 1
#     if row['process_daysC'] == 0 :
#         return 0
#     else: return np.nan

# %%
full['process_day_>=1'] = full.apply (lambda row: label_process_day_1(row), axis=1)
full['process_day_>=7'] = full.apply (lambda row: label_process_day_7(row), axis=1)
# full['process_dayA_>=1'] = full.apply (lambda row: label_process_dayA_1(row), axis=1)
# full['process_dayC_>=1'] = full.apply (lambda row: label_process_dayC_1(row), axis=1)
full['Medical_X_LPPN'] = full['Field:Medical Needs Score'] * full['Field:LPPN Score']

# %% [markdown]
# ###  Check for Null values

# %% [markdown]
# field names, values, and percentage missing

# %%
full.shape
# Out:
# (7676, 340)

# %%
null_count = pd.Series.to_frame(full.isna().sum())
# null_count.rename(columns={"0": "null_count"})
null_count.columns = ["null_counts"]
null_count["total_counts"] = full.shape[0]
null_count["null_percent"] = np.round(null_count["null_counts"] / full.shape[0] , 5)
null_count["dtype"] = pd.Series.to_frame(full.dtypes)
null_count["sample_value"] = full.mode()[:1].T
null_count
# Out:
#                         null_counts  total_counts  null_percent  \
# Mona Unique Session ID         6590          7676       0.85852
# Mona Unique User ID             199          7676       0.02592
# Created on                     6590          7676       0.85852
# Created by                     6590          7676       0.85852
# Pipeline                       6590          7676       0.85852
# ...                             ...           ...           ...
# Field:Pause Handoffs           4811          7676       0.62676
# Field:Lebanon Location         7019          7676       0.91441
# process_day_>=1                6898          7676       0.89865
# process_day_>=7                6890          7676       0.89760
# Medical_X_LPPN                 6865          7676       0.89435
#
#                                  dtype  \
# Mona Unique Session ID          object
# Mona Unique User ID             object
# Created on              datetime64[ns]
# Created by                      object
# Pipeline                        object
# ...                                ...
# Field:Pause Handoffs            object
# Field:Lebanon Location          object
# process_day_>=1                float64
# process_day_>=7                float64
# Medical_X_LPPN                 float64
#
#                                                              sample_value
# Mona Unique Session ID  003b4c8a-fa26-4d7c-bb47-c27109b757e3.2019-07-2...
# Mona Unique User ID                  217a088b-d4ce-408f-a5d8-c4eedc4aeb9f
# Created on                                            2019-12-11 06:01:52
# Created by                                                   Brooke Sauro
# Pipeline                                                             Mona
# ...                                                                   ...
# Field:Pause Handoffs                                                  Yes
# Field:Lebanon Location                                               نعم.
# process_day_>=1                                                         0
# process_day_>=7                                                         0
# Medical_X_LPPN                                                          0
#
# [340 rows x 5 columns]

# %%
null_count.sort_values(['null_counts'],ascending = False)
# Out:
#                                     null_counts  total_counts  null_percent  \
# Field:RFR within deadline                  7675          7676       0.99987
# Field:I130 Info Response                   7675          7676       0.99987
# Field:Mexico Passport Type                 7675          7676       0.99987
# Field:DAP as Relative of SIV               7675          7676       0.99987
# Field:Aggr 3 Reason Unable to Move         7674          7676       0.99974
# ...                                         ...           ...           ...
# Language                                   1055          7676       0.13744
# URN:Facebook                                887          7676       0.11555
# Name                                        296          7676       0.03856
# Mona Unique User ID                         199          7676       0.02592
# Created On                                  199          7676       0.02592
#
#                                              dtype  \
# Field:RFR within deadline                   object
# Field:I130 Info Response                    object
# Field:Mexico Passport Type                  object
# Field:DAP as Relative of SIV                object
# Field:Aggr 3 Reason Unable to Move          object
# ...                                            ...
# Language                                    object
# URN:Facebook                               float64
# Name                                        object
# Mona Unique User ID                         object
# Created On                          datetime64[ns]
#
#                                                                          sample_value
# Field:RFR within deadline                                            jsv80uRFRv0wnixf
# Field:I130 Info Response                     كيف ابدأ بتفعيل الطلب المقدم من جهة اختي
# Field:Mexico Passport Type                                                Replacement
# Field:DAP as Relative of SIV                                   DAP as Relative of SIV
# Field:Aggr 3 Reason Unable to Move  Reason Unable to Move: عدم تنقلي سببه انه بعد ...
# ...                                                                               ...
# Language                                                                          ara
# URN:Facebook                                                              1.22442e+15
# Name                                                                             محمد
# Mona Unique User ID                              217a088b-d4ce-408f-a5d8-c4eedc4aeb9f
# Created On                                                        2019-10-16 19:25:50
#
# [340 rows x 5 columns]

# %%
# null_count.to_csv("null_counts_full.csv")

# %% [markdown]
# ### Data cleanup

# %%
full_clean = full.copy()

# %%
pd.set_option("max_rows", None)

pd.reset_option("max_rows")

# %%
full['Field:Gender']
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 7671       NaN
# 7672       NaN
# 7673       NaN
# 7674       NaN
# 7675       NaN
# Name: Field:Gender, Length: 7676, dtype: object

# %% [markdown]
# #### change to / create new binary field indicating (null vs. not null)

# %%
def create_binary_field(df, column_name):
    df[column_name+"_binary"] = df[column_name].apply(lambda x: 0 if pd.isnull(x) else 1)

# %%
def changeto_binary_field(df, column_name):
    if df[column_name].isna().sum() == 0:
        print("[log]: no change")
        return
    
    df[column_name] = df[column_name].apply(lambda x: 0 if pd.isnull(x) else 1)
    print("[log]: Updated to binary null/not null")

# %%
'Field:I130 Info Rating'[6:]
# Out:
# 'I130 Info Rating'

# %%
for i in ['Field:Aggr 3 Reason Unable to Move',
'Field:I130 Info Rating',
'Field:Aggr 3 Mst Svr Threat',
'Field:DAPI130 Info Rating',
'Field:Aggr 2 Mst Svr Threat',
'Field:Aggr 3 Mst Svr Only Threats',
'Field:P3 Info Rating',
'Field:Aggr 3 Mst Svr Attack',
'Field:Aggr 3 Attack Within Last 6 Months',
'Field:Aggr 2 Reason Unable to Move',
'Field:Aggr 3 Threat Within Last 6 Months',
'Field:Women and Girls Severity Assessment',
'Field:DAPEV Info Rating',
'Field:Canadian Sponsorship Info Rating',
'Field:Aggr 1 Reason Unable to Move',
'Field:Nationality2',
'Field:Email Address1',
'Field:I 130 F',
'Field:Worked for USG',
'Field:Aggr 1 Mst Svr Only Threats',
         'Field:Age',
'Field:End Feedback Helpfulness Rating',
'Field:End Feedback Recommend Rating',
'Field:German Reunification Info Rating',
'Field:Lebanon UNHCR Info Rating',
'Field:Medical Needs Score',
'Field:Years in Current Country',
'Field:Traumatic Incident 1 Assessment',
'Field:Aggressor 2 Score',
'Field:Medical Condition 1 Assessment',
'Field:Medical Condition 1 Score',
'Field:Medical Condition 2 Score',
'Field:Medical Condition 3 Score',
'Field:Aggr 1 SVT Rating',
'Field:Aggressor 1 Score',
'Field:Medical Condition 2 Assessment',
'Field:Aggr 1 Threat Within Last 6 Months',
'Field:ICORN Info Rating',
'Field:Aggr 1 Attack Within Last 6 Months',
'Field:Traumatic Incident 2 Assessment',
'Field:Aggr 1 Mst Svr Attack',
'Field:USRAP Info Rating',
'Field:Aggr 2 SVT Rating',
'Field:Medical Condition 3 Assessment',
'Field:Aggr 2 Threat Within Last 6 Months',
'Field:Aggr 2 Attack Within Last 6 Months',
'Field:Aggr 2 Mst Svr Only Threats',
'Field:Aggr 1 Mst Svr Threat',
'Field:Aggr 3 SVT Rating',
'Field:Aggressor 3 Score',
'Field:Aggr 2 Mst Svr Attack']:
    changeto_binary_field(full_clean,i)
    print(full[i].value_counts())
    print(full_clean[i].value_counts())
    print("-"*30)
# Out:
# [log]: Updated to binary null/not null
# Reason Unable to Move: عدم تنقلي سببه انه بعد المراجعات الى الافرع الامنيه اخبروني باني اذا غيرت سكني يجب ابلاغهم على الفور    1
# Reason Unable to Move: ولك خلص                                                                                                 1
# Name: Field:Aggr 3 Reason Unable to Move, dtype: int64
# 0    7674
# 1       2
# Name: Field:Aggr 3 Reason Unable to Move, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 4.0    1
# 5.0    1
# Name: Field:I130 Info Rating, dtype: int64
# 0    7674
# 1       2
# Name: Field:I130 Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                     1
# Severity of Most Serious Threat: 5    1
# Severity of Most Serious Threat: 4    1
# Name: Field:Aggr 3 Mst Svr Threat, dtype: int64
# 0    7673
# 1       3
# Name: Field:Aggr 3 Mst Svr Threat, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    5
# Name: Field:DAPI130 Info Rating, dtype: int64
# 0    7671
# 1       5
# Name: Field:DAPI130 Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                     2
# Severity of Most Serious Threat: 3    2
# Severity of Most Serious Threat: 5    1
# 2                                     1
# Name: Field:Aggr 2 Mst Svr Threat, dtype: int64
# 0    7670
# 1       6
# Name: Field:Aggr 2 Mst Svr Threat, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                                     4
# Severity of Most Serious Threat if Only Threats: 5    2
# Severity of Most Serious Threat if Only Threats: 4    2
# Severity of Most Serious Threat if Only Threats: 2    2
# Name: Field:Aggr 3 Mst Svr Only Threats, dtype: int64
# 0    7666
# 1      10
# Name: Field:Aggr 3 Mst Svr Only Threats, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    7
# 1.0    3
# 2.0    1
# Name: Field:P3 Info Rating, dtype: int64
# 0    7665
# 1      11
# Name: Field:P3 Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                     5
# Severity of Most Serious Attack: 4    2
# Severity of Most Serious Attack: 1    1
# Severity of Most Serious Attack: 5    1
# 3                                     1
# Severity of Most Serious Attack: 2    1
# Severity of Most Serious Attack: 3    1
# Name: Field:Aggr 3 Mst Svr Attack, dtype: int64
# 0    7664
# 1      12
# Name: Field:Aggr 3 Mst Svr Attack, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                     3
# Attack Severity: 2    3
# Attack Severity: 1    2
# Attack Severity: 4    2
# Attack Severity: 5    2
# 3                     1
# 4                     1
# Name: Field:Aggr 3 Attack Within Last 6 Months, dtype: int64
# 0    7662
# 1      14
# Name: Field:Aggr 3 Attack Within Last 6 Months, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Reason Unable to Move: غير قادر على نقل سكني بسبب ان البلديات في لبنان تمنع دخول السوريين من مناطق أخرى داخل لبنان مع العلم أنني حاولت ولكن كان الرفض يتم من البلديه وكانت مفوضية الأمم في لبنان ومكتب الحمايه على إطلاع كامل لقضيتي وكانو قد وعدوني لتأمين سكن بديل وحتى هذه اللحظه لم يساعدوني بشيء    1
# Reason Unable to Move: لآنني لااملك المال                                                                                                                                                                                                                                                                1
# Reason Unable to Move: ليس لدي اي معارف او اقارب في لبنان .. جئت لهذه المنطقة منذ مايقارب ٧ سنين واعمل بها منذ ذلك الحين                                                                                                                                                                                 1
# Reason Unable to Move: بسبب القدرة المادية المحدودة و انهم يعلمون كل شي عننا                                                                                                                                                                                                                             1
# Reason Unable to Move: ليس لدي مال                                                                                                                                                                                                                                                                       1
# Reason Unable to Move: لااملك المال                                                                                                                                                                                                                                                                      1
# Reason Unable to Move: ظروف المعيشة الغالية                                                                                                                                                                                                                                                              1
# Reason Unable to Move: زوجي غير قادر ان ياخذ شقة لان شغله قليل                                                                                                                                                                                                                                           1
# Reason Unable to Move: ليس لدي القدرة بسبب دفع الأجور ونقص المال والظروف الصعبة                                                                                                                                                                                                                          1
# Reason Unable to Move: لان ليس لدي اقامة قانونية في لبنان                                                                                                                                                                                                                                                1
# Reason Unable to Move: لأنني لاملك القدرة المالية حاليا للانتقال وبسبب غلاء الاجار                                                                                                                                                                                                                       1
# Reason Unable to Move: الوضع المادي                                                                                                                                                                                                                                                                      1
# Reason Unable to Move: كون الاشخاص الذين اعرفهم يسكنون في هذه المنطقه وليس لي اناس اعرفهم في مناطق اخره                                                                                                                                                                                                  1
# Reason Unable to Move: لعدم قدرتي على دفع الأجور السكنية لأنني عاطل عن العمل لعدم امتلاكي اجازة عمل من الحكومة اللبنانية                                                                                                                                                                                 1
# Reason Unable to Move: بسبب مدارس الاولاد\nاذا انتقلت لمكان اخر لايسمحو لهم بالنقل\nوبسبب جلسات المحكمة التي يقدمها ضدي بين الحين والاخر، والعمل في الرياض متوفر اكثر من باقي المحافظات الاخره\nوعملي مرتبط في سياحة الاطعام، والعاصمة فيها موارد وفرص اكثر                                              1
# Reason Unable to Move: السبب الرئيسي مادي                                                                                                                                                                                                                                                                1
# Reason Unable to Move: اسباب ماليه                                                                                                                                                                                                                                                                       1
# Name: Field:Aggr 2 Reason Unable to Move, dtype: int64
# 0    7659
# 1      17
# Name: Field:Aggr 2 Reason Unable to Move, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                     7
# Threat Severity: 5    4
# Threat Severity: 2    3
# Threat Severity: 4    3
# Threat Severity: 3    2
# 3                     1
# Name: Field:Aggr 3 Threat Within Last 6 Months, dtype: int64
# 0    7656
# 1      20
# Name: Field:Aggr 3 Threat Within Last 6 Months, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5    7
# 3    6
# 1    5
# 4    2
# ١    1
# ٥    1
# 2    1
# Name: Field:Women and Girls Severity Assessment, dtype: int64
# 0    7653
# 1      23
# Name: Field:Women and Girls Severity Assessment, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    14
# 3.0     7
# 1.0     7
# 4.0     5
# 2.0     2
# 0.0     1
# Name: Field:DAPEV Info Rating, dtype: int64
# 0    7640
# 1      36
# Name: Field:DAPEV Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                                          289
# 3                                                          156
# 1                                                          125
# 4                                                           95
# 2                                                           94
# ١                                                            7
# ٢                                                            2
# لم افهم                                                      2
# ٣                                                            2
# مقبول الى حد ما                                              1
# ٥                                                            1
# 5 5                                                          1
# اريد ان اعلم كيف يمكنني ترشيح ملفي للسفر                     1
# كيف يعني                                                     1
# ما فهمت                                                      1
# ٠                                                            1
# أنا عندي مشكله ارجو التواصل معي وعلى الرغم0096176569246      1
# 👍                                                            1
# ما هي مقاطعة كيبك                                            1
# يعني ماذا                                                    1
# ٤                                                            1
# Name: Field:Canadian Sponsorship Info Rating, dtype: int64
# 0    6892
# 1     784
# Name: Field:Canadian Sponsorship Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Reason Unable to Move: انا ابحث عن منزل اخر ولكن لم اجد حتى الان                                                                                               2
# Reason Unable to Move: السبب مادي                                                                                                                              2
# Reason Unable to Move: بسبب الوضع المادي ولاستغلال في المناطق الاخرة                                                                                           2
# Reason Unable to Move: بسبب الوضع الاقتصادي                                                                                                                    1
# Reason Unable to Move: بس الوضع المادي                                                                                                                         1
#                                                                                                                                                               ..
# Reason Unable to Move: لعدم قدرتي على دفع الأجور السكنية لأنني عاطل عن العمل لعدم امتلاكي اجازة عمل من الحكومة اللبنانية                                       1
# Reason Unable to Move: Lack of communication and money                                                                                                         1
# Reason Unable to Move: انا اعمل ناطور بناية \nوهو ساكن ضمن البناية \nولا استطيع تغيير المكان \nلان لايوجد لدي مردود مالي لكي ادفع اجار البيت ومصروف العائلة    1
# Reason Unable to Move: بسب غلاء اجور البيوت                                                                                                                    1
# Reason Unable to Move: بسبب ارتفاع اسعار البيوت                                                                                                                1
# Name: Field:Aggr 1 Reason Unable to Move, Length: 75, dtype: int64
# 0    7598
# 1      78
# Name: Field:Aggr 1 Reason Unable to Move, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# لا                      8
# Kurd                    7
# فلسطينية                7
# فلسطيني                 5
# Palestinian             4
# كردي                    4
# كرديه                   3
# فلسطيني سوري            3
# لبنانيه                 2
# سوريا                   2
# انا من اكراد سورية      1
# لاتوجد                  1
# سورية.                  1
# ليس لدي                 1
# التركية                 1
# Lebanese                1
# اصل تركي                1
# والدتي البنانيه         1
# سوداني                  1
# سوري.                   1
# لايوجد سوري             1
# فلسطينية سورية          1
# انا فلسطينه سوريه       1
# إثيوبيا                 1
# مصري                    1
# كردية                   1
# Somalian.               1
# لا يوجد غير سوري        1
# كرداي                   1
# سوريه                   1
# فلسطينيه سوريه          1
# لا جنسية واحدة  فقط.    1
# Usa                     1
# تركية                   1
# امريكية                 1
# تركمانية                1
# لبنانية                 1
# قومية كردية             1
# جنسيتي فلسطيني          1
# فلسطينة                 1
# اني سكان الاردن         1
# Jordanian               1
# قصدى انا كردي سورى      1
# ارمنيا                  1
# ليس لدي تخربطت.         1
# سودانيه.                1
# Name: Field:Nationality2, dtype: int64
# 0    7595
# 1      81
# Name: Field:Nationality2, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Waelbadwi319@gmail.com       3
# Www.ghadaselo@gmail.com      3
# fraslwyn@gmail.com           2
# Mohammadrajab22@jmail.com    2
# raghebalyounis@gmail.com     2
#                             ..
# hamada.www@hotmail.com       1
# Soaadmelhem2@gmail.com       1
# bkr12345hosenza@gmail.com    1
# Loieeabbass@gmail.com        1
# Heba.mree.sy@gmail.com       1
# Name: Field:Email Address1, Length: 957, dtype: int64
# 0    6686
# 1     990
# Name: Field:Email Address1, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# I-130 F    20
# Name: Field:I 130 F, dtype: int64
# 0    7656
# 1      20
# Name: Field:I 130 F, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Worked for USG    49
# Name: Field:Worked for USG, dtype: int64
# 0    7627
# 1      49
# Name: Field:Worked for USG, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Severity of Most Serious Threat if Only Threats: 5    33
# 5                                                     31
# Severity of Most Serious Threat if Only Threats: 4    23
# Severity of Most Serious Threat if Only Threats: 3    20
# 3                                                     18
# 1                                                     14
# 4                                                     13
# Severity of Most Serious Threat if Only Threats: 1    10
# Severity of Most Serious Threat if Only Threats: 2    10
# 2                                                      7
# ٥                                                      1
# Name: Field:Aggr 1 Mst Svr Only Threats, dtype: int64
# 0    7496
# 1     180
# Name: Field:Aggr 1 Mst Svr Only Threats, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 35.0      381
# 30.0      312
# 29.0      254
# 25.0      233
# 27.0      231
#          ...
# 1986.0      1
# 13.0        1
# 72.0        1
# 15.0        1
# 1981.0      1
# Name: Field:Age, Length: 74, dtype: int64
# 1    5138
# 0    2538
# Name: Field:Age, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5    2477
# 3     538
# 4     538
# 1     524
# 2     221
# ٥      10
# ٣       6
# ١       6
# ٤       5
# ٢       2
# Name: Field:End Feedback Helpfulness Rating, dtype: int64
# 1    4327
# 0    3349
# Name: Field:End Feedback Helpfulness Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 10    1914
# 1      400
# 5      354
# 6      305
# 8      239
# 7      231
# 9      160
# 3      124
# 4      114
# 2       97
# ١٠      26
# ١        5
# ٩        3
# ٥        3
# ٤        3
# ٣        2
# ٧        2
# ٨        2
# ٦        1
# ٢        1
# Name: Field:End Feedback Recommend Rating, dtype: int64
# 1    3986
# 0    3690
# Name: Field:End Feedback Recommend Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                                                                                              615
# 1                                                                                                              321
# 3                                                                                                              300
# 2                                                                                                              189
# 4                                                                                                              177
# ١                                                                                                                5
# ٢                                                                                                                3
# ٣                                                                                                                3
# ٥                                                                                                                3
# ٤                                                                                                                3
# لم افهم                                                                                                          2
# مقبول الى حد ما                                                                                                  1
# كثيرا                                                                                                            1
# انا من اربع شهور سجلت المعلومات عندكن في ايراب ولهلق ماحدحكا معي على سفر                                         1
# ولله مابعرف فايتة بلحيط                                                                                          1
# بس ابنتي فوق ١٨ وماحسنت تقدم لنا لم شمل                                                                          1
# ماستفدت لان لازم اشرح وضعي ضروري                                                                                 1
# لم استفد شيئا                                                                                                    1
# حسنا                                                                                                             1
# ووضعي انا يندرج ضمن الحالات الانسانيه التي تريدها الدول الاوربيه لاعاده التوطين وارجو المساعده في هذا الامر      1
# لااعرف                                                                                                           1
# لبنان متواحد                                                                                                     1
# يعطيكون العافية                                                                                                  1
# لم افهم شيئ                                                                                                      1
# انا ليس لدي معيل واصدقائي واختي لايقدمون المساعدة لي ارجو منك ان تساعديني باللممرات الانسانية                    1
# لا افهم                                                                                                          1
# جيد                                                                                                              1
# كنت اعمل محامي بسوريا هل يفيدني ذلك                                                                              1
# هل أزا يوجد اخ يستطيع عمل لم الشمل او أم                                                                         1
# يامنى اريد السفر                                                                                                 1
# لا يفيدني بشيئ                                                                                                   1
# لدي سؤال؟                                                                                                        1
# ولا شي                                                                                                           1
# Name: Field:German Reunification Info Rating, dtype: int64
# 0    6033
# 1    1643
# Name: Field:German Reunification Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                                                              444
# 1                                                                              185
# 3                                                                              176
# 4                                                                              127
# 2                                                                              111
# ١                                                                                8
# 0                                                                                3
# ٤                                                                                3
# لم افهم                                                                          2
# ٢                                                                                2
# ٥                                                                                2
# لاشي                                                                             1
# استفادتي انا ام انتم ..                                                          1
# طيب ماهي علاقة المفوظية معكم                                                     1
# مافهمت                                                                           1
# ؟                                                                                1
# جيدا                                                                             1
# رقم الملف بالبيت وانا خارج البيت                                                 1
# كيف بدي اعرف ملفي قبل لاسفر                                                      1
# نعم                                                                              1
# بعد سنتين ونصف من انتظار بعد مقابلة توطين الى استراليا صدمت في الرفض             1
# هذا رقم الملف                                                                    1
# 🔟                                                                                1
# لايوجداستفادة                                                                    1
# انت لم تقدم لي اي خدمة او معلومة انت فقط حققت معي وكانك جاهز استخباراتي فقط      1
# اريد السفر                                                                       1
# ٣                                                                                1
# لا افهم المقصود                                                                  1
# صار عنده خوف وحاله نفسيه من الشباب                                               1
# Name: Field:Lebanon UNHCR Info Rating, dtype: int64
# 0    6595
# 1    1081
# Name: Field:Lebanon UNHCR Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 0.0    470
# 5.0    211
# 4.0    129
# 6.0    127
# 3.0     76
# 2.0     27
# 1.0     18
# Name: Field:Medical Needs Score, dtype: int64
# 0    6618
# 1    1058
# Name: Field:Medical Needs Score, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 7.000000e+00    218
# 6.000000e+00    215
# 5.000000e+00    152
# 8.000000e+00    112
# 4.000000e+00    101
# 2.000000e+00     82
# 3.000000e+00     69
# 1.000000e+00     51
# 9.000000e+00     17
# 1.234000e+03      8
# 2.013000e+03      5
# 2.500000e+00      2
# 2.012000e+03      2
# 1.000000e-01      2
# 1.200000e+01      1
# 8.000000e-01      1
# 3.500000e+00      1
# 2.015000e+03      1
# 3.123400e+00      1
# 7.000000e-01      1
# 1.234567e+06      1
# 5.800000e+01      1
# 6.000000e-01      1
# 2.011000e+03      1
# 2.014000e+03      1
# 5.200000e+01      1
# Name: Field:Years in Current Country, dtype: int64
# 0    6628
# 1    1048
# Name: Field:Years in Current Country, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    398
# 3.0    138
# 4.0    124
# 1.0     81
# 2.0     50
# Name: Field:Traumatic Incident 1 Assessment, dtype: int64
# 0    6885
# 1     791
# Name: Field:Traumatic Incident 1 Assessment, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 0.0    487
# 6.0     75
# 3.0     26
# 1.0     25
# 2.0     19
# 4.0     18
# 5.0      6
# Name: Field:Aggressor 2 Score, dtype: int64
# 0    7020
# 1     656
# Name: Field:Aggressor 2 Score, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5    250
# 3    129
# 4    121
# 2     49
# 1     39
# ٥      3
# ١      1
# Name: Field:Medical Condition 1 Assessment, dtype: int64
# 0    7084
# 1     592
# Name: Field:Medical Condition 1 Assessment, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    190
# 4.0    125
# 3.0    104
# 6.0    104
# 2.0     44
# 1.0     25
# Name: Field:Medical Condition 1 Score, dtype: int64
# 0    7084
# 1     592
# Name: Field:Medical Condition 1 Score, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 0.0    245
# 5.0     94
# 4.0     82
# 3.0     71
# 6.0     56
# 2.0     30
# 1.0     13
# Name: Field:Medical Condition 2 Score, dtype: int64
# 0    7085
# 1     591
# Name: Field:Medical Condition 2 Score, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 0.0    444
# 4.0     43
# 3.0     29
# 5.0     29
# 6.0     24
# 1.0     12
# 2.0      9
# Name: Field:Medical Condition 3 Score, dtype: int64
# 0    7086
# 1     590
# Name: Field:Medical Condition 3 Score, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Aggressor SVT Rating: 0    166
# 0                          154
# 5                           61
# Aggressor SVT Rating: 5     56
# Aggressor SVT Rating: 3     34
# 3                           34
# Aggressor SVT Rating: 4     20
# 4                           15
# 2                           14
# Aggressor SVT Rating: 2     10
# Aggressor SVT Rating: 1      9
# 1                            7
# Name: Field:Aggr 1 SVT Rating, dtype: int64
# 0    7096
# 1     580
# Name: Field:Aggr 1 SVT Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 6.0    251
# 3.0     91
# 4.0     84
# 1.0     76
# 2.0     39
# 5.0     33
# 0.0      1
# Name: Field:Aggressor 1 Score, dtype: int64
# 0    7101
# 1     575
# Name: Field:Aggressor 1 Score, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    126
# 3.0     82
# 4.0     82
# 2.0     42
# 1.0     16
# Name: Field:Medical Condition 2 Assessment, dtype: int64
# 0    7328
# 1     348
# Name: Field:Medical Condition 2 Assessment, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                     74
# Threat Severity: 5    69
# 3                     41
# Threat Severity: 4    40
# Threat Severity: 3    25
# 4                     22
# Threat Severity: 2    14
# Threat Severity: 1    12
# 1                     12
# 2                     10
# ٤                      1
# ١                      1
# Name: Field:Aggr 1 Threat Within Last 6 Months, dtype: int64
# 0    7355
# 1     321
# Name: Field:Aggr 1 Threat Within Last 6 Months, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                                                         129
# 3                                                                          53
# 1                                                                          36
# 4                                                                          34
# 2                                                                          28
# حسنا                                                                        2
# ٣                                                                           1
# ٥                                                                           1
# شكرا لكم ولكني لم تفيدوني باي شي مع اني معرض للخطر المحدق فينا وبعألتي      1
# مرحبا                                                                       1
# نعم                                                                         1
# 👍                                                                           1
# Name: Field:ICORN Info Rating, dtype: int64
# 0    7388
# 1     288
# Name: Field:ICORN Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Attack Severity: 1    42
# Attack Severity: 3    40
# 1                     34
# 5                     31
# Attack Severity: 5    28
# 3                     27
# 2                     18
# Attack Severity: 2    16
# 4                     10
# Attack Severity: 4     9
# ٢                      3
# ١                      1
# ٥                      1
# Name: Field:Aggr 1 Attack Within Last 6 Months, dtype: int64
# 0    7416
# 1     260
# Name: Field:Aggr 1 Attack Within Last 6 Months, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    141
# 4.0     43
# 3.0     31
# 1.0     22
# 2.0     18
# Name: Field:Traumatic Incident 2 Assessment, dtype: int64
# 0    7421
# 1     255
# Name: Field:Traumatic Incident 2 Assessment, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Severity of Most Serious Attack: 5    34
# 5                                     32
# 1                                     25
# 3                                     22
# Severity of Most Serious Attack: 3    20
# Severity of Most Serious Attack: 4    17
# Severity of Most Serious Attack: 1    14
# 4                                     14
# 2                                     14
# Severity of Most Serious Attack: 2     9
# ٣                                      1
# ١                                      1
# ٥                                      1
# Name: Field:Aggr 1 Mst Svr Attack, dtype: int64
# 0    7472
# 1     204
# Name: Field:Aggr 1 Mst Svr Attack, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                                                                               86
# 3                                                                                               31
# 1                                                                                               31
# 4                                                                                               26
# 2                                                                                               21
# بس  انا ما دقولي  كرمال السفر انا قدمت وما ردولي خبر ... اذا فيكن تساعدوني وتقدمولي  طلب سفر     1
# ١                                                                                                1
# لايوجد جديد                                                                                      1
# كلا                                                                                              1
# Name: Field:USRAP Info Rating, dtype: int64
# 0    7477
# 1     199
# Name: Field:USRAP Info Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Aggressor SVT Rating: 0    48
# 0                          39
# 5                          23
# Aggressor SVT Rating: 5    22
# Aggressor SVT Rating: 3    10
# 3                           9
# Aggressor SVT Rating: 4     6
# Aggressor SVT Rating: 1     5
# 4                           3
# Aggressor SVT Rating: 2     3
# 2                           3
# 1                           1
# Name: Field:Aggr 2 SVT Rating, dtype: int64
# 0    7504
# 1     172
# Name: Field:Aggr 2 SVT Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5.0    46
# 3.0    39
# 4.0    38
# 1.0    15
# 2.0     9
# Name: Field:Medical Condition 3 Assessment, dtype: int64
# 0    7529
# 1     147
# Name: Field:Medical Condition 3 Assessment, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Threat Severity: 5    22
# 5                     20
# 3                     16
# Threat Severity: 3     9
# Threat Severity: 1     8
# 1                      6
# Threat Severity: 4     6
# 4                      5
# Threat Severity: 2     3
# 2                      3
# Name: Field:Aggr 2 Threat Within Last 6 Months, dtype: int64
# 0    7578
# 1      98
# Name: Field:Aggr 2 Threat Within Last 6 Months, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Attack Severity: 1    11
# Attack Severity: 2    10
# Attack Severity: 4    10
# 5                      8
# Attack Severity: 5     8
# Attack Severity: 3     7
# 1                      6
# 3                      5
# 2                      5
# 4                      4
# Name: Field:Aggr 2 Attack Within Last 6 Months, dtype: int64
# 0    7602
# 1      74
# Name: Field:Aggr 2 Attack Within Last 6 Months, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 3                                                     13
# Severity of Most Serious Threat if Only Threats: 5    10
# 5                                                      8
# Severity of Most Serious Threat if Only Threats: 1     6
# Severity of Most Serious Threat if Only Threats: 4     5
# 1                                                      4
# Severity of Most Serious Threat if Only Threats: 2     4
# 2                                                      4
# Severity of Most Serious Threat if Only Threats: 3     3
# 4                                                      1
# Name: Field:Aggr 2 Mst Svr Only Threats, dtype: int64
# 0    7618
# 1      58
# Name: Field:Aggr 2 Mst Svr Only Threats, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Severity of Most Serious Threat: 5    12
# 5                                     11
# 4                                      4
# 3                                      3
# Severity of Most Serious Threat: 3     2
# Severity of Most Serious Threat: 1     1
# ١                                      1
# Severity of Most Serious Threat: 4     1
# Severity of Most Serious Threat: 2     1
# 2                                      1
# Name: Field:Aggr 1 Mst Svr Threat, dtype: int64
# 0    7639
# 1      37
# Name: Field:Aggr 1 Mst Svr Threat, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# Aggressor SVT Rating: 0    7
# 5                          6
# 0                          4
# Aggressor SVT Rating: 2    4
# Aggressor SVT Rating: 4    4
# 3                          3
# Aggressor SVT Rating: 5    3
# Aggressor SVT Rating: 3    2
# Name: Field:Aggr 3 SVT Rating, dtype: int64
# 0    7643
# 1      33
# Name: Field:Aggr 3 SVT Rating, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 0.0    691
# 6.0     19
# 2.0      6
# 5.0      3
# 1.0      2
# 4.0      2
# 3.0      2
# Name: Field:Aggressor 3 Score, dtype: int64
# 0    6951
# 1     725
# Name: Field:Aggressor 3 Score, dtype: int64
# ------------------------------
# [log]: Updated to binary null/not null
# 5                                     13
# Severity of Most Serious Attack: 5    11
# 3                                      6
# Severity of Most Serious Attack: 3     6
# Severity of Most Serious Attack: 1     5
# 4                                      4
# Severity of Most Serious Attack: 4     4
# 1                                      4
# Severity of Most Serious Attack: 2     3
# 2                                      3
# Name: Field:Aggr 2 Mst Svr Attack, dtype: int64
# 0    7617
# 1      59
# Name: Field:Aggr 2 Mst Svr Attack, dtype: int64
# ------------------------------

# %% [markdown]
# #### Specific cleaner for adult and marriage variables

# %%
def create_adult_field(df, column_name='Field:Minor or Adult'):
    if "Adult" not in df.columns:
        df["Adult"] = df[column_name].apply(lambda x: 1 if x=="Adult" else 0)
        df.drop(columns=[column_name])
        print("Done")
    else:
        print("Already created Adult column")

# %%
create_adult_field(full_clean)
# Out:
# Done

# %%
def create_married_field(df, column_name='Field:Marital Status'):
    if "Married" not in df.columns:
        df["Married"] = df[column_name].apply(lambda x: 1 if x=="Married" else 0)
        df.drop(columns=[column_name])
        print("Done")
    else:
        print("Already created Married column")

# %%
create_married_field(full_clean)
# Out:
# Done

# %% [markdown]
# #### String cleaning to numeric

# %%
import re
def string_to_int(string):
    end_num = re.compile('(\d)\s*.*$')
    try:
        return(int(end_num.findall(string)[0]))
    except: return(np.nan)

# %%
string_to_int("3.0")
# Out:
# 3

# %%
def convert_to_numeric(df, column_name):
    new = df[column_name].apply(lambda x: string_to_int(str(x)))
    df[column_name] = new

# %%
for i in ['Field:USRAP Info Rating',
'Field:Aggr 1 Mst Svr Attack',
'Field:Traumatic Incident 2 Assessment',
'Field:Aggr 1 Attack Within Last 6 Months',
'Field:ICORN Info Rating',
'Field:Aggr 1 Threat Within Last 6 Months',
'Field:Medical Condition 2 Assessment',
'Field:Traumatic Incident 1 Assessment',
'Field:Lebanon UNHCR Info Rating',
'Field:German Reunification Info Rating',
'Field:Aggr 1 Mst Svr Threat',
'Field:Aggr 2 Mst Svr Only Threats',
'Field:Aggr 2 Attack Within Last 6 Months',
'Field:Aggr 2 Threat Within Last 6 Months',
'Field:Medical Condition 3 Assessment',
'Field:Aggr 2 SVT Rating',
'Field:Aggr 3 SVT Rating',
'Field:Aggressor 1 Score',
'Field:Aggr 1 SVT Rating',
'Field:Medical Condition 3 Score',
'Field:Medical Condition 2 Score',
'Field:Medical Condition 1 Assessment',
'Field:Medical Condition 1 Score',
'Field:Aggressor 2 Score',
'Field:Years in Current Country',
'Field:Medical Needs Score',
'Field:End Feedback Recommend Rating',
'Field:End Feedback Helpfulness Rating',
'Field:Age',
'Field:Aggr 2 Mst Svr Attack',
'Field:Aggressor 3 Score']:
    convert_to_numeric(full_clean,i)
    print(full[i].value_counts())
    print(full_clean[i].value_counts())
    print("-"*30)
# Out:
# 5                                                                                               86
# 3                                                                                               31
# 1                                                                                               31
# 4                                                                                               26
# 2                                                                                               21
# بس  انا ما دقولي  كرمال السفر انا قدمت وما ردولي خبر ... اذا فيكن تساعدوني وتقدمولي  طلب سفر     1
# ١                                                                                                1
# لايوجد جديد                                                                                      1
# كلا                                                                                              1
# Name: Field:USRAP Info Rating, dtype: int64
# 0    7477
# 1     199
# Name: Field:USRAP Info Rating, dtype: int64
# ------------------------------
# Severity of Most Serious Attack: 5    34
# 5                                     32
# 1                                     25
# 3                                     22
# Severity of Most Serious Attack: 3    20
# Severity of Most Serious Attack: 4    17
# Severity of Most Serious Attack: 1    14
# 4                                     14
# 2                                     14
# Severity of Most Serious Attack: 2     9
# ٣                                      1
# ١                                      1
# ٥                                      1
# Name: Field:Aggr 1 Mst Svr Attack, dtype: int64
# 0    7472
# 1     204
# Name: Field:Aggr 1 Mst Svr Attack, dtype: int64
# ------------------------------
# 5.0    141
# 4.0     43
# 3.0     31
# 1.0     22
# 2.0     18
# Name: Field:Traumatic Incident 2 Assessment, dtype: int64
# 0    7421
# 1     255
# Name: Field:Traumatic Incident 2 Assessment, dtype: int64
# ------------------------------
# Attack Severity: 1    42
# Attack Severity: 3    40
# 1                     34
# 5                     31
# Attack Severity: 5    28
# 3                     27
# 2                     18
# Attack Severity: 2    16
# 4                     10
# Attack Severity: 4     9
# ٢                      3
# ١                      1
# ٥                      1
# Name: Field:Aggr 1 Attack Within Last 6 Months, dtype: int64
# 0    7416
# 1     260
# Name: Field:Aggr 1 Attack Within Last 6 Months, dtype: int64
# ------------------------------
# 5                                                                         129
# 3                                                                          53
# 1                                                                          36
# 4                                                                          34
# 2                                                                          28
# حسنا                                                                        2
# ٣                                                                           1
# ٥                                                                           1
# شكرا لكم ولكني لم تفيدوني باي شي مع اني معرض للخطر المحدق فينا وبعألتي      1
# مرحبا                                                                       1
# نعم                                                                         1
# 👍                                                                           1
# Name: Field:ICORN Info Rating, dtype: int64
# 0    7388
# 1     288
# Name: Field:ICORN Info Rating, dtype: int64
# ------------------------------
# 5                     74
# Threat Severity: 5    69
# 3                     41
# Threat Severity: 4    40
# Threat Severity: 3    25
# 4                     22
# Threat Severity: 2    14
# Threat Severity: 1    12
# 1                     12
# 2                     10
# ٤                      1
# ١                      1
# Name: Field:Aggr 1 Threat Within Last 6 Months, dtype: int64
# 0    7355
# 1     321
# Name: Field:Aggr 1 Threat Within Last 6 Months, dtype: int64
# ------------------------------
# 5.0    126
# 3.0     82
# 4.0     82
# 2.0     42
# 1.0     16
# Name: Field:Medical Condition 2 Assessment, dtype: int64
# 0    7328
# 1     348
# Name: Field:Medical Condition 2 Assessment, dtype: int64
# ------------------------------
# 5.0    398
# 3.0    138
# 4.0    124
# 1.0     81
# 2.0     50
# Name: Field:Traumatic Incident 1 Assessment, dtype: int64
# 0    6885
# 1     791
# Name: Field:Traumatic Incident 1 Assessment, dtype: int64
# ------------------------------
# 5                                                                              444
# 1                                                                              185
# 3                                                                              176
# 4                                                                              127
# 2                                                                              111
# ١                                                                                8
# 0                                                                                3
# ٤                                                                                3
# لم افهم                                                                          2
# ٢                                                                                2
# ٥                                                                                2
# لاشي                                                                             1
# استفادتي انا ام انتم ..                                                          1
# طيب ماهي علاقة المفوظية معكم                                                     1
# مافهمت                                                                           1
# ؟                                                                                1
# جيدا                                                                             1
# رقم الملف بالبيت وانا خارج البيت                                                 1
# كيف بدي اعرف ملفي قبل لاسفر                                                      1
# نعم                                                                              1
# بعد سنتين ونصف من انتظار بعد مقابلة توطين الى استراليا صدمت في الرفض             1
# هذا رقم الملف                                                                    1
# 🔟                                                                                1
# لايوجداستفادة                                                                    1
# انت لم تقدم لي اي خدمة او معلومة انت فقط حققت معي وكانك جاهز استخباراتي فقط      1
# اريد السفر                                                                       1
# ٣                                                                                1
# لا افهم المقصود                                                                  1
# صار عنده خوف وحاله نفسيه من الشباب                                               1
# Name: Field:Lebanon UNHCR Info Rating, dtype: int64
# 0    6595
# 1    1081
# Name: Field:Lebanon UNHCR Info Rating, dtype: int64
# ------------------------------
# 5                                                                                                              615
# 1                                                                                                              321
# 3                                                                                                              300
# 2                                                                                                              189
# 4                                                                                                              177
# ١                                                                                                                5
# ٢                                                                                                                3
# ٣                                                                                                                3
# ٥                                                                                                                3
# ٤                                                                                                                3
# لم افهم                                                                                                          2
# مقبول الى حد ما                                                                                                  1
# كثيرا                                                                                                            1
# انا من اربع شهور سجلت المعلومات عندكن في ايراب ولهلق ماحدحكا معي على سفر                                         1
# ولله مابعرف فايتة بلحيط                                                                                          1
# بس ابنتي فوق ١٨ وماحسنت تقدم لنا لم شمل                                                                          1
# ماستفدت لان لازم اشرح وضعي ضروري                                                                                 1
# لم استفد شيئا                                                                                                    1
# حسنا                                                                                                             1
# ووضعي انا يندرج ضمن الحالات الانسانيه التي تريدها الدول الاوربيه لاعاده التوطين وارجو المساعده في هذا الامر      1
# لااعرف                                                                                                           1
# لبنان متواحد                                                                                                     1
# يعطيكون العافية                                                                                                  1
# لم افهم شيئ                                                                                                      1
# انا ليس لدي معيل واصدقائي واختي لايقدمون المساعدة لي ارجو منك ان تساعديني باللممرات الانسانية                    1
# لا افهم                                                                                                          1
# جيد                                                                                                              1
# كنت اعمل محامي بسوريا هل يفيدني ذلك                                                                              1
# هل أزا يوجد اخ يستطيع عمل لم الشمل او أم                                                                         1
# يامنى اريد السفر                                                                                                 1
# لا يفيدني بشيئ                                                                                                   1
# لدي سؤال؟                                                                                                        1
# ولا شي                                                                                                           1
# Name: Field:German Reunification Info Rating, dtype: int64
# 0    6033
# 1    1643
# Name: Field:German Reunification Info Rating, dtype: int64
# ------------------------------
# Severity of Most Serious Threat: 5    12
# 5                                     11
# 4                                      4
# 3                                      3
# Severity of Most Serious Threat: 3     2
# Severity of Most Serious Threat: 1     1
# ١                                      1
# Severity of Most Serious Threat: 4     1
# Severity of Most Serious Threat: 2     1
# 2                                      1
# Name: Field:Aggr 1 Mst Svr Threat, dtype: int64
# 0    7639
# 1      37
# Name: Field:Aggr 1 Mst Svr Threat, dtype: int64
# ------------------------------
# 3                                                     13
# Severity of Most Serious Threat if Only Threats: 5    10
# 5                                                      8
# Severity of Most Serious Threat if Only Threats: 1     6
# Severity of Most Serious Threat if Only Threats: 4     5
# 1                                                      4
# Severity of Most Serious Threat if Only Threats: 2     4
# 2                                                      4
# Severity of Most Serious Threat if Only Threats: 3     3
# 4                                                      1
# Name: Field:Aggr 2 Mst Svr Only Threats, dtype: int64
# 0    7618
# 1      58
# Name: Field:Aggr 2 Mst Svr Only Threats, dtype: int64
# ------------------------------
# Attack Severity: 1    11
# Attack Severity: 2    10
# Attack Severity: 4    10
# 5                      8
# Attack Severity: 5     8
# Attack Severity: 3     7
# 1                      6
# 3                      5
# 2                      5
# 4                      4
# Name: Field:Aggr 2 Attack Within Last 6 Months, dtype: int64
# 0    7602
# 1      74
# Name: Field:Aggr 2 Attack Within Last 6 Months, dtype: int64
# ------------------------------
# Threat Severity: 5    22
# 5                     20
# 3                     16
# Threat Severity: 3     9
# Threat Severity: 1     8
# 1                      6
# Threat Severity: 4     6
# 4                      5
# Threat Severity: 2     3
# 2                      3
# Name: Field:Aggr 2 Threat Within Last 6 Months, dtype: int64
# 0    7578
# 1      98
# Name: Field:Aggr 2 Threat Within Last 6 Months, dtype: int64
# ------------------------------
# 5.0    46
# 3.0    39
# 4.0    38
# 1.0    15
# 2.0     9
# Name: Field:Medical Condition 3 Assessment, dtype: int64
# 0    7529
# 1     147
# Name: Field:Medical Condition 3 Assessment, dtype: int64
# ------------------------------
# Aggressor SVT Rating: 0    48
# 0                          39
# 5                          23
# Aggressor SVT Rating: 5    22
# Aggressor SVT Rating: 3    10
# 3                           9
# Aggressor SVT Rating: 4     6
# Aggressor SVT Rating: 1     5
# 4                           3
# Aggressor SVT Rating: 2     3
# 2                           3
# 1                           1
# Name: Field:Aggr 2 SVT Rating, dtype: int64
# 0    7504
# 1     172
# Name: Field:Aggr 2 SVT Rating, dtype: int64
# ------------------------------
# Aggressor SVT Rating: 0    7
# 5                          6
# 0                          4
# Aggressor SVT Rating: 2    4
# Aggressor SVT Rating: 4    4
# 3                          3
# Aggressor SVT Rating: 5    3
# Aggressor SVT Rating: 3    2
# Name: Field:Aggr 3 SVT Rating, dtype: int64
# 0    7643
# 1      33
# Name: Field:Aggr 3 SVT Rating, dtype: int64
# ------------------------------
# 6.0    251
# 3.0     91
# 4.0     84
# 1.0     76
# 2.0     39
# 5.0     33
# 0.0      1
# Name: Field:Aggressor 1 Score, dtype: int64
# 0    7101
# 1     575
# Name: Field:Aggressor 1 Score, dtype: int64
# ------------------------------
# Aggressor SVT Rating: 0    166
# 0                          154
# 5                           61
# Aggressor SVT Rating: 5     56
# Aggressor SVT Rating: 3     34
# 3                           34
# Aggressor SVT Rating: 4     20
# 4                           15
# 2                           14
# Aggressor SVT Rating: 2     10
# Aggressor SVT Rating: 1      9
# 1                            7
# Name: Field:Aggr 1 SVT Rating, dtype: int64
# 0    7096
# 1     580
# Name: Field:Aggr 1 SVT Rating, dtype: int64
# ------------------------------
# 0.0    444
# 4.0     43
# 3.0     29
# 5.0     29
# 6.0     24
# 1.0     12
# 2.0      9
# Name: Field:Medical Condition 3 Score, dtype: int64
# 0    7086
# 1     590
# Name: Field:Medical Condition 3 Score, dtype: int64
# ------------------------------
# 0.0    245
# 5.0     94
# 4.0     82
# 3.0     71
# 6.0     56
# 2.0     30
# 1.0     13
# Name: Field:Medical Condition 2 Score, dtype: int64
# 0    7085
# 1     591
# Name: Field:Medical Condition 2 Score, dtype: int64
# ------------------------------
# 5    250
# 3    129
# 4    121
# 2     49
# 1     39
# ٥      3
# ١      1
# Name: Field:Medical Condition 1 Assessment, dtype: int64
# 0    7084
# 1     592
# Name: Field:Medical Condition 1 Assessment, dtype: int64
# ------------------------------
# 5.0    190
# 4.0    125
# 3.0    104
# 6.0    104
# 2.0     44
# 1.0     25
# Name: Field:Medical Condition 1 Score, dtype: int64
# 0    7084
# 1     592
# Name: Field:Medical Condition 1 Score, dtype: int64
# ------------------------------
# 0.0    487
# 6.0     75
# 3.0     26
# 1.0     25
# 2.0     19
# 4.0     18
# 5.0      6
# Name: Field:Aggressor 2 Score, dtype: int64
# 0    7020
# 1     656
# Name: Field:Aggressor 2 Score, dtype: int64
# ------------------------------
# 7.000000e+00    218
# 6.000000e+00    215
# 5.000000e+00    152
# 8.000000e+00    112
# 4.000000e+00    101
# 2.000000e+00     82
# 3.000000e+00     69
# 1.000000e+00     51
# 9.000000e+00     17
# 1.234000e+03      8
# 2.013000e+03      5
# 2.500000e+00      2
# 2.012000e+03      2
# 1.000000e-01      2
# 1.200000e+01      1
# 8.000000e-01      1
# 3.500000e+00      1
# 2.015000e+03      1
# 3.123400e+00      1
# 7.000000e-01      1
# 1.234567e+06      1
# 5.800000e+01      1
# 6.000000e-01      1
# 2.011000e+03      1
# 2.014000e+03      1
# 5.200000e+01      1
# Name: Field:Years in Current Country, dtype: int64
# 0    6628
# 1    1048
# Name: Field:Years in Current Country, dtype: int64
# ------------------------------
# 0.0    470
# 5.0    211
# 4.0    129
# 6.0    127
# 3.0     76
# 2.0     27
# 1.0     18
# Name: Field:Medical Needs Score, dtype: int64
# 0    6618
# 1    1058
# Name: Field:Medical Needs Score, dtype: int64
# ------------------------------
# 10    1914
# 1      400
# 5      354
# 6      305
# 8      239
# 7      231
# 9      160
# 3      124
# 4      114
# 2       97
# ١٠      26
# ١        5
# ٩        3
# ٥        3
# ٤        3
# ٣        2
# ٧        2
# ٨        2
# ٦        1
# ٢        1
# Name: Field:End Feedback Recommend Rating, dtype: int64
# 1    3986
# 0    3690
# Name: Field:End Feedback Recommend Rating, dtype: int64
# ------------------------------
# 5    2477
# 3     538
# 4     538
# 1     524
# 2     221
# ٥      10
# ٣       6
# ١       6
# ٤       5
# ٢       2
# Name: Field:End Feedback Helpfulness Rating, dtype: int64
# 1    4327
# 0    3349
# Name: Field:End Feedback Helpfulness Rating, dtype: int64
# ------------------------------
# 35.0      381
# 30.0      312
# 29.0      254
# 25.0      233
# 27.0      231
#          ...
# 1986.0      1
# 13.0        1
# 72.0        1
# 15.0        1
# 1981.0      1
# Name: Field:Age, Length: 74, dtype: int64
# 1    5138
# 0    2538
# Name: Field:Age, dtype: int64
# ------------------------------
# 5                                     13
# Severity of Most Serious Attack: 5    11
# 3                                      6
# Severity of Most Serious Attack: 3     6
# Severity of Most Serious Attack: 1     5
# 4                                      4
# Severity of Most Serious Attack: 4     4
# 1                                      4
# Severity of Most Serious Attack: 2     3
# 2                                      3
# Name: Field:Aggr 2 Mst Svr Attack, dtype: int64
# 0    7617
# 1      59
# Name: Field:Aggr 2 Mst Svr Attack, dtype: int64
# ------------------------------
# 0.0    691
# 6.0     19
# 2.0      6
# 5.0      3
# 1.0      2
# 4.0      2
# 3.0      2
# Name: Field:Aggressor 3 Score, dtype: int64
# 0    6951
# 1     725
# Name: Field:Aggressor 3 Score, dtype: int64
# ------------------------------

# %% [markdown]
# #### Arabic to English

# %%
def convert_arabic_boolean(df, column_name, as_yes, as_no):
    if as_yes not in df[column_name].values and as_no not in df[column_name].values:
        print("[log]: no change")
        return
#     new = df[column_name].apply(lambda x: "Yes" if x==as_yes else ("No" if x==as_no else (np.nan if x!="Yes" and x!="No" else x)))
    new = df[column_name].apply(lambda x: "Yes" if x==as_yes else "No")

    df[column_name] = new
    print("[log]: converted "+column_name)

# %%
arrabic_no = "لا"

# %%
arrabic_yes = "نعم"

# %%
for i in ['Field:Medical Condition 3 Inc Treatment',
'Field:Medical Condition 3 SVT',
'Field:Medical Condition 3 Treatment Abroad',
'Field:Traumatic Incident 2 Ong Mdl Needs',
'Field:Medical Condition 2 Inc Treatment',
'Field:Medical Condition 2 SVT',
'Field:Medical Condition 2 Treatment Abroad',
'Field:Medical Condition 1 Inc Treatment',
'Field:Medical Condition 1 SVT',
'Field:Medical Condition 1 Treatment Abroad',
'Field:Traumatic Incident 1 Ong Mdl Needs']:
    convert_arabic_boolean(full_clean,i,arrabic_yes,arrabic_no)
    print(full[i].value_counts())
    print(full_clean[i].value_counts())
    print("-"*30)
# Out:
# [log]: converted Field:Medical Condition 3 Inc Treatment
# لا     99
# نعم    46
# No      2
# Name: Field:Medical Condition 3 Inc Treatment, dtype: int64
# No     7630
# Yes      46
# Name: Field:Medical Condition 3 Inc Treatment, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 3 SVT
# لا     100
# نعم     45
# Yes      2
# Name: Field:Medical Condition 3 SVT, dtype: int64
# No     7631
# Yes      45
# Name: Field:Medical Condition 3 SVT, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 3 Treatment Abroad
# نعم        106
# لا أعلم     35
# لا           4
# Yes          2
# Name: Field:Medical Condition 3 Treatment Abroad, dtype: int64
# No     7570
# Yes     106
# Name: Field:Medical Condition 3 Treatment Abroad, dtype: int64
# ------------------------------
# [log]: converted Field:Traumatic Incident 2 Ong Mdl Needs
# لا     230
# نعم     99
# No       1
# Name: Field:Traumatic Incident 2 Ong Mdl Needs, dtype: int64
# No     7577
# Yes      99
# Name: Field:Traumatic Incident 2 Ong Mdl Needs, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 2 Inc Treatment
# لا     246
# نعم    100
# No       2
# Name: Field:Medical Condition 2 Inc Treatment, dtype: int64
# No     7576
# Yes     100
# Name: Field:Medical Condition 2 Inc Treatment, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 2 SVT
# لا     225
# نعم    121
# Yes      2
# Name: Field:Medical Condition 2 SVT, dtype: int64
# No     7555
# Yes     121
# Name: Field:Medical Condition 2 SVT, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 2 Treatment Abroad
# نعم        244
# لا أعلم     95
# لا           7
# Yes          2
# Name: Field:Medical Condition 2 Treatment Abroad, dtype: int64
# No     7432
# Yes     244
# Name: Field:Medical Condition 2 Treatment Abroad, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 1 Inc Treatment
# لا     467
# نعم    121
# No       4
# Name: Field:Medical Condition 1 Inc Treatment, dtype: int64
# No     7555
# Yes     121
# Name: Field:Medical Condition 1 Inc Treatment, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 1 SVT
# لا     366
# نعم    222
# Yes      3
# No       1
# Name: Field:Medical Condition 1 SVT, dtype: int64
# No     7454
# Yes     222
# Name: Field:Medical Condition 1 SVT, dtype: int64
# ------------------------------
# [log]: converted Field:Medical Condition 1 Treatment Abroad
# نعم             404
# لا أعلم         170
# لا               14
# Yes               3
# I'm not sure      1
# Name: Field:Medical Condition 1 Treatment Abroad, dtype: int64
# No     7272
# Yes     404
# Name: Field:Medical Condition 1 Treatment Abroad, dtype: int64
# ------------------------------
# [log]: converted Field:Traumatic Incident 1 Ong Mdl Needs
# لا     489
# نعم    295
# Yes      5
# No       2
# Name: Field:Traumatic Incident 1 Ong Mdl Needs, dtype: int64
# No     7381
# Yes     295
# Name: Field:Traumatic Incident 1 Ong Mdl Needs, dtype: int64
# ------------------------------

# %% [markdown]
# #### Custom convert null vs. not null

# %%
# convert null
def convert_to(df, column_name, not_null_as, null_as):
    if df[column_name].isna().sum() == 0:
        print("[log]: no change")
        return
    new = df[column_name].apply(lambda x: not_null_as if not pd.isnull(x) else null_as)
    df[column_name] = new
    print("[log]: converted "+column_name)

# %%
for i in ['Field:I 130 IR',
'Field:SIV Follow to Join',
'Field:P 3',
'Field:SIV',
'Field:DAP via EV',
'Field:DAP as Relative of SIV',
'Field:EO Waiver',
'Field:SIV 101a',
'Field:SIV 1059',
'Field:DAP via I 130',
'Field:ICORN CPJ',
'Field:Canadian Private Sponsorship',
'Field:Germany Family Reunification']:
    convert_to(full_clean,i,"Eligible","Not Eligible")
    print(full[i].value_counts())
    print(full_clean[i].value_counts())
    print("-"*30)
# Out:
# [log]: converted Field:I 130 IR
# I-130 IR    3
# Name: Field:I 130 IR, dtype: int64
# Not Eligible    7673
# Eligible           3
# Name: Field:I 130 IR, dtype: int64
# ------------------------------
# [log]: converted Field:SIV Follow to Join
# SIV Follow to Join    3
# Name: Field:SIV Follow to Join, dtype: int64
# Not Eligible    7673
# Eligible           3
# Name: Field:SIV Follow to Join, dtype: int64
# ------------------------------
# [log]: converted Field:P 3
# P-3    8
# Name: Field:P 3, dtype: int64
# Not Eligible    7668
# Eligible           8
# Name: Field:P 3, dtype: int64
# ------------------------------
# [log]: converted Field:SIV
# SIV    12
# Name: Field:SIV, dtype: int64
# Not Eligible    7664
# Eligible          12
# Name: Field:SIV, dtype: int64
# ------------------------------
# [log]: converted Field:DAP via EV
# DAP via EV    24
# Name: Field:DAP via EV, dtype: int64
# Not Eligible    7652
# Eligible          24
# Name: Field:DAP via EV, dtype: int64
# ------------------------------
# [log]: converted Field:DAP as Relative of SIV
# DAP as Relative of SIV    1
# Name: Field:DAP as Relative of SIV, dtype: int64
# Not Eligible    7675
# Eligible           1
# Name: Field:DAP as Relative of SIV, dtype: int64
# ------------------------------
# [log]: converted Field:EO Waiver
# EO Waiver    2
# Name: Field:EO Waiver, dtype: int64
# Not Eligible    7674
# Eligible           2
# Name: Field:EO Waiver, dtype: int64
# ------------------------------
# [log]: converted Field:SIV 101a
# 101(a) SIV    4
# Name: Field:SIV 101a, dtype: int64
# Not Eligible    7672
# Eligible           4
# Name: Field:SIV 101a, dtype: int64
# ------------------------------
# [log]: converted Field:SIV 1059
# 1059 SIV    4
# Name: Field:SIV 1059, dtype: int64
# Not Eligible    7672
# Eligible           4
# Name: Field:SIV 1059, dtype: int64
# ------------------------------
# [log]: converted Field:DAP via I 130
# DAP via I-130    19
# Name: Field:DAP via I 130, dtype: int64
# Not Eligible    7657
# Eligible          19
# Name: Field:DAP via I 130, dtype: int64
# ------------------------------
# [log]: converted Field:ICORN CPJ
# ICORN CPJ    251
# Name: Field:ICORN CPJ, dtype: int64
# Not Eligible    7425
# Eligible         251
# Name: Field:ICORN CPJ, dtype: int64
# ------------------------------
# [log]: converted Field:Canadian Private Sponsorship
# Canadian Private Sponsorship    698
# Name: Field:Canadian Private Sponsorship, dtype: int64
# Not Eligible    6978
# Eligible         698
# Name: Field:Canadian Private Sponsorship, dtype: int64
# ------------------------------
# [log]: converted Field:Germany Family Reunification
# Germany Family Reunification    1501
# Name: Field:Germany Family Reunification, dtype: int64
# Not Eligible    6175
# Eligible        1501
# Name: Field:Germany Family Reunification, dtype: int64
# ------------------------------

# %%
for i in ['Field:Aggr 3 Threats Since Moving',
'Field:RFR Submission',
'Field:US Prior Admission',
'Field:Aggr 3 Moved to Avoid Aggr',
'Field:Testing Only',
'Field:Family Worked for USG',
'ILI Assistance Provided ',
'Field:RFR',
'Field:Aggr 2 Moved to Avoid Aggr',
'Flags',
'Field:Aggr 1 Threats Since Moving',
'Field:USRAP Access',
'Field:Aggr 1 Moved to Avoid Aggr',
'Field:Multiple Incidents',
'Field:Vulnerability Assessed',
'URN:Telegram',
'Field:Lack of Durable Solutions',
'Field:Women and Girls at Risk',
'Field:SVT',
'Field:LGBT',
'Field:Hired Lawyer',
'Field:Pause Handoffs',
'Field:Prescreening Complete',
'Field:Ongoing USRAP',
'Field:Previous US Resettlement',
'URN:Facebook']:
    convert_to(full_clean,i,"Yes","No")
    print(full[i].value_counts())
    print(full_clean[i].value_counts())
    print("-"*30)
# Out:
# [log]: converted Field:Aggr 3 Threats Since Moving
# Received Threats Since Moving: Yes    11
# Name: Field:Aggr 3 Threats Since Moving, dtype: int64
# No     7665
# Yes      11
# Name: Field:Aggr 3 Threats Since Moving, dtype: int64
# ------------------------------
# [log]: converted Field:RFR Submission
# RFR Submission    11
# Name: Field:RFR Submission, dtype: int64
# No     7665
# Yes      11
# Name: Field:RFR Submission, dtype: int64
# ------------------------------
# [log]: converted Field:US Prior Admission
# RTD/RRV    15
# Name: Field:US Prior Admission, dtype: int64
# No     7661
# Yes      15
# Name: Field:US Prior Admission, dtype: int64
# ------------------------------
# [log]: converted Field:Aggr 3 Moved to Avoid Aggr
# Moved to Avoid This Aggressor: Yes       11
# Moved to Avoid This Aggressor: Unable     9
# Name: Field:Aggr 3 Moved to Avoid Aggr, dtype: int64
# No     7656
# Yes      20
# Name: Field:Aggr 3 Moved to Avoid Aggr, dtype: int64
# ------------------------------
# [log]: converted Field:Testing Only
# Yes    21
# Name: Field:Testing Only, dtype: int64
# No     7655
# Yes      21
# Name: Field:Testing Only, dtype: int64
# ------------------------------
# [log]: converted Field:Family Worked for USG
# Family member worked for USG    35
# Name: Field:Family Worked for USG, dtype: int64
# No     7641
# Yes      35
# Name: Field:Family Worked for USG, dtype: int64
# ------------------------------
# [log]: converted ILI Assistance Provided
# Non-Legal Services Information                            35
# Pro Se Guidance                                            5
# Non-Legal Services Referral                                2
# Vulnerability RST or Protection Referral (Unspecified)     1
# Name: ILI Assistance Provided , dtype: int64
# No     7633
# Yes      43
# Name: ILI Assistance Provided , dtype: int64
# ------------------------------
# [log]: converted Field:RFR
# RFR    57
# Name: Field:RFR, dtype: int64
# No     7619
# Yes      57
# Name: Field:RFR, dtype: int64
# ------------------------------
# [log]: converted Field:Aggr 2 Moved to Avoid Aggr
# Moved to Avoid This Aggressor: Unable    46
# Moved to Avoid This Aggressor: Yes       34
# Moved to Avoid This Aggressor: No        14
# Name: Field:Aggr 2 Moved to Avoid Aggr, dtype: int64
# No     7582
# Yes      94
# Name: Field:Aggr 2 Moved to Avoid Aggr, dtype: int64
# ------------------------------
# [log]: converted Flags
# Unresponsive    97
# Name: Flags, dtype: int64
# No     7579
# Yes      97
# Name: Flags, dtype: int64
# ------------------------------
# [log]: converted Field:Aggr 1 Threats Since Moving
# Received Threats Since Moving: Yes    78
# Received Threats Since Moving: No     38
# Name: Field:Aggr 1 Threats Since Moving, dtype: int64
# No     7560
# Yes     116
# Name: Field:Aggr 1 Threats Since Moving, dtype: int64
# ------------------------------
# [log]: converted Field:USRAP Access
# USRAP Access    176
# Name: Field:USRAP Access, dtype: int64
# No     7500
# Yes     176
# Name: Field:USRAP Access, dtype: int64
# ------------------------------
# [log]: converted Field:Aggr 1 Moved to Avoid Aggr
# Moved to Avoid This Aggressor: Unable    150
# Moved to Avoid This Aggressor: Yes       118
# Moved to Avoid This Aggressor: No         27
# Name: Field:Aggr 1 Moved to Avoid Aggr, dtype: int64
# No     7381
# Yes     295
# Name: Field:Aggr 1 Moved to Avoid Aggr, dtype: int64
# ------------------------------
# [log]: converted Field:Multiple Incidents
# Yes    453
# Name: Field:Multiple Incidents, dtype: int64
# No     7223
# Yes     453
# Name: Field:Multiple Incidents, dtype: int64
# ------------------------------
# [log]: converted Field:Vulnerability Assessed
# Vulnerability Assessed    470
# Name: Field:Vulnerability Assessed, dtype: int64
# No     7206
# Yes     470
# Name: Field:Vulnerability Assessed, dtype: int64
# ------------------------------
# [log]: converted URN:Telegram
# alshwele1     1
# 1057767387    1
# 991291684     1
# wa3ez         1
# 822659597     1
#              ..
# 885518731     1
# 1061709102    1
# eehhee9804    1
# 859305097     1
# 715032904     1
# Name: URN:Telegram, Length: 688, dtype: int64
# No     6988
# Yes     688
# Name: URN:Telegram, dtype: int64
# ------------------------------
# [log]: converted Field:Lack of Durable Solutions
# YES    736
# Name: Field:Lack of Durable Solutions, dtype: int64
# No     6940
# Yes     736
# Name: Field:Lack of Durable Solutions, dtype: int64
# ------------------------------
# [log]: converted Field:Women and Girls at Risk
# NO     797
# YES     23
# Name: Field:Women and Girls at Risk, dtype: int64
# No     6856
# Yes     820
# Name: Field:Women and Girls at Risk, dtype: int64
# ------------------------------
# [log]: converted Field:SVT
# YES     794
# NO      203
# SKIP     60
# Name: Field:SVT, dtype: int64
# No     6619
# Yes    1057
# Name: Field:SVT, dtype: int64
# ------------------------------
# [log]: converted Field:LGBT
# NO     1040
# YES      39
# Name: Field:LGBT, dtype: int64
# No     6597
# Yes    1079
# Name: Field:LGBT, dtype: int64
# ------------------------------
# [log]: converted Field:Hired Lawyer
# No     1100
# Yes      61
# Name: Field:Hired Lawyer, dtype: int64
# No     6515
# Yes    1161
# Name: Field:Hired Lawyer, dtype: int64
# ------------------------------
# [log]: converted Field:Pause Handoffs
# Yes    2865
# Name: Field:Pause Handoffs, dtype: int64
# No     4811
# Yes    2865
# Name: Field:Pause Handoffs, dtype: int64
# ------------------------------
# [log]: converted Field:Prescreening Complete
# Yes    3512
# Name: Field:Prescreening Complete, dtype: int64
# No     4164
# Yes    3512
# Name: Field:Prescreening Complete, dtype: int64
# ------------------------------
# [log]: converted Field:Ongoing USRAP
# No        2563
# Unsure    1398
# Yes        540
# Name: Field:Ongoing USRAP, dtype: int64
# Yes    4501
# No     3175
# Name: Field:Ongoing USRAP, dtype: int64
# ------------------------------
# [log]: converted Field:Previous US Resettlement
# No     4422
# Yes      79
# Name: Field:Previous US Resettlement, dtype: int64
# Yes    4501
# No     3175
# Name: Field:Previous US Resettlement, dtype: int64
# ------------------------------
# [log]: converted URN:Facebook
# 2.457410e+15    3
# 2.398684e+15    3
# 1.224419e+15    3
# 2.037946e+15    3
# 2.379934e+15    3
#                ..
# 2.611178e+15    1
# 2.760626e+15    1
# 3.098175e+15    1
# 2.600490e+15    1
# 2.928034e+15    1
# Name: URN:Facebook, Length: 6744, dtype: int64
# Yes    6789
# No      887
# Name: URN:Facebook, dtype: int64
# ------------------------------

# %%
convert_to(full_clean,"Vulnerability Threshold","Above","Below")
# Out:
# [log]: converted Vulnerability Threshold

# %%
convert_to(full_clean,'Field:RFR within deadline',"Yes","Not Applicable")
# Out:
# [log]: converted Field:RFR within deadline

# %% [markdown]
# #### Convert single variable formats

# %%
# convert 'Field:Aggr 2 Threats Since Moving'
def convert_threats(df, column_name='Field:Aggr 2 Threats Since Moving'):
    if df[column_name].isna().sum() == 0:
        print("[log]: no change")
        return
    new = df[column_name].apply(lambda x: "Yes" if x=="Received Threats Since Moving: Yes" else ("No" if x == "Received Threats Since Moving: No" else "Not Applicable"))
    df[column_name] = new
    print("[log]: converted "+column_name)

# %%
convert_threats(full_clean)
print(full['Field:Aggr 2 Threats Since Moving'].value_counts())
print(full_clean['Field:Aggr 2 Threats Since Moving'].value_counts())
# Out:
# [log]: converted Field:Aggr 2 Threats Since Moving
# Received Threats Since Moving: Yes    19
# Received Threats Since Moving: No     15
# Name: Field:Aggr 2 Threats Since Moving, dtype: int64
# Not Applicable    7642
# Yes                 19
# No                  15
# Name: Field:Aggr 2 Threats Since Moving, dtype: int64

# %%
# convert 'Field:End Feedback Follow Up Conversation'
def convert_follow_up(df, column_name='Field:End Feedback Follow Up Conversation'):
    if df[column_name].isna().sum() == 0:
        print("[log]: no change")
        return
    new = df[column_name].apply(lambda x: x if not pd.isnull(x) else "Not Applicable")
    df[column_name] = new
    print("[log]: converted "+column_name)

# %%
convert_follow_up(full_clean)
# Out:
# [log]: converted Field:End Feedback Follow Up Conversation

# %%
full_clean = full_clean[full_clean['Field:Testing Only']=="No"]
full_clean = full_clean.drop(columns=['Field:Testing Only'])

# %% [markdown]
# ### Cleaned data Output

# %%
cleaned = full_clean[['Vulnerability Threshold',
'Field:Aggr 3 Threats Since Moving',
'Field:RFR Submission',
'Field:US Prior Admission',
'Field:Aggr 3 Moved to Avoid Aggr',
'Field:Family Worked for USG',
'ILI Assistance Provided ',
'Field:RFR',
'Field:Aggr 2 Moved to Avoid Aggr',
'Flags',
'Field:Aggr 1 Threats Since Moving',
'Field:USRAP Access',
'Field:Aggr 1 Moved to Avoid Aggr',
'Field:Multiple Incidents',
'Field:Vulnerability Assessed',
'URN:Telegram',
'Field:Lack of Durable Solutions',
'Field:Women and Girls at Risk',
'Field:SVT',
'Field:LGBT',
'Field:Hired Lawyer',
'Field:Pause Handoffs',
'Field:Prescreening Complete',
'Field:Ongoing USRAP',
'Field:Previous US Resettlement',
'URN:Facebook',
'Field:RFR within deadline',
'Field:Aggr 2 Threats Since Moving',
'Field:End Feedback Follow Up Conversation',
'Field:I 130 IR',
'Field:SIV Follow to Join',
'Field:P 3',
'Field:SIV',
'Field:DAP via EV',
'Field:DAP as Relative of SIV',
'Field:EO Waiver',
'Field:SIV 101a',
'Field:SIV 1059',
'Field:DAP via I 130',
'Field:ICORN CPJ',
'Field:Canadian Private Sponsorship',
'Field:Germany Family Reunification',
'Field:Medical Condition 3 Inc Treatment',
'Field:Medical Condition 3 SVT',
'Field:Medical Condition 3 Treatment Abroad',
'Field:Traumatic Incident 2 Ong Mdl Needs',
'Field:Medical Condition 2 Inc Treatment',
'Field:Medical Condition 2 SVT',
'Field:Medical Condition 2 Treatment Abroad',
'Field:Medical Condition 1 Inc Treatment',
'Field:Medical Condition 1 SVT',
'Field:Medical Condition 1 Treatment Abroad',
'Field:Traumatic Incident 1 Ong Mdl Needs',
'Field:Handoff Timestamp',
'Date of Screening Decision',
'Created On',
'Field:USRAP Info Rating',
'Field:Aggr 1 Mst Svr Attack',
'Field:Traumatic Incident 2 Assessment',
'Field:Aggr 1 Attack Within Last 6 Months',
'Field:ICORN Info Rating',
'Field:Aggr 1 Threat Within Last 6 Months',
'Field:Medical Condition 2 Assessment',
'Field:Traumatic Incident 1 Assessment',
'Field:Lebanon UNHCR Info Rating',
'Field:German Reunification Info Rating',
'Field:Aggr 1 Mst Svr Threat',
'Field:Aggr 2 Mst Svr Only Threats',
'Field:Aggr 2 Attack Within Last 6 Months',
'Field:Aggr 2 Threat Within Last 6 Months',
'Field:Medical Condition 3 Assessment',
'Field:Aggr 2 SVT Rating',
'Field:Aggr 3 SVT Rating',
'Field:Aggressor 1 Score',
'Field:Aggr 1 SVT Rating',
'Field:Years in Current Country',
'Field:Medical Needs Score',
'Field:End Feedback Recommend Rating',
'Field:End Feedback Helpfulness Rating',
'Field:Age',
'Field:Aggr 2 Mst Svr Attack',
'Field:Aggressor 3 Score',
'Adult',
'Married',
'Client Location (Country)',
'Client Nationality',
'Field:Current Country',
'Field:Nationality1',
'Field:Gender',
'Language',
'Field:Aggr 3 Reason Unable to Move',
'Field:I130 Info Rating',
'Field:Aggr 3 Mst Svr Threat',
'Field:DAPI130 Info Rating',
'Field:Aggr 2 Mst Svr Threat',
'Field:Aggr 3 Mst Svr Only Threats',
'Field:P3 Info Rating',
'Field:Aggr 3 Mst Svr Attack',
'Field:Aggr 3 Attack Within Last 6 Months',
'Field:Aggr 2 Reason Unable to Move',
'Field:Aggr 3 Threat Within Last 6 Months',
'Field:Women and Girls Severity Assessment',
'Field:DAPEV Info Rating',
'Field:Canadian Sponsorship Info Rating',
'Field:Aggr 1 Reason Unable to Move',
'Field:Nationality2',
'Field:Email Address1',
'Field:I 130 F',
'Field:Worked for USG',
'Field:Aggr 1 Mst Svr Only Threats',
'Medical_X_LPPN',
'Field:LPPN Score',
'Screening Decision',
'Date of Screening Start',
'Program Eligibilities',
'Date of Referral',
'First Referral',
'In IRAP Process']]

# %%
cleaned
# Out:
#      Vulnerability Threshold Field:Aggr 3 Threats Since Moving  \
# 0                      Above                                No
# 1                      Below                                No
# 2                      Below                                No
# 3                      Below                                No
# 4                      Above                                No
# ...                      ...                               ...
# 7671                   Below                                No
# 7672                   Below                                No
# 7673                   Below                                No
# 7674                   Below                                No
# 7675                   Below                                No
#
#      Field:RFR Submission Field:US Prior Admission  \
# 0                      No                       No
# 1                      No                       No
# 2                      No                       No
# 3                      No                       No
# 4                      No                       No
# ...                   ...                      ...
# 7671                   No                       No
# 7672                   No                       No
# 7673                   No                       No
# 7674                   No                       No
# 7675                   No                       No
#
#      Field:Aggr 3 Moved to Avoid Aggr Field:Family Worked for USG  \
# 0                                  No                          No
# 1                                  No                          No
# 2                                  No                          No
# 3                                  No                          No
# 4                                  No                          No
# ...                               ...                         ...
# 7671                               No                          No
# 7672                               No                          No
# 7673                               No                          No
# 7674                               No                          No
# 7675                               No                          No
#
#      ILI Assistance Provided  Field:RFR Field:Aggr 2 Moved to Avoid Aggr  \
# 0                          No        No                               No
# 1                          No        No                               No
# 2                          No        No                               No
# 3                          No        No                              Yes
# 4                          No        No                               No
# ...                       ...       ...                              ...
# 7671                       No        No                               No
# 7672                       No        No                               No
# 7673                       No        No                               No
# 7674                       No        No                               No
# 7675                       No        No                               No
#
#      Flags  ... process_day_>=7 process_days Medical_X_LPPN Field:LPPN Score  \
# 0       No  ...             0.0          0.0            NaN              NaN
# 1       No  ...             NaN          NaN            NaN              NaN
# 2       No  ...             NaN          NaN            NaN              NaN
# 3       No  ...             NaN          NaN            0.0              6.0
# 4       No  ...             0.0          0.0            0.0              0.0
# ...    ...  ...             ...          ...            ...              ...
# 7671    No  ...             NaN          NaN            NaN              NaN
# 7672    No  ...             NaN          NaN            NaN              NaN
# 7673    No  ...             NaN          NaN            NaN              NaN
# 7674    No  ...             NaN          NaN            NaN              NaN
# 7675    No  ...             NaN          NaN            NaN              NaN
#
#      Screening Decision Date of Screening Start  \
# 0      Cannot Represent              2019-08-12
# 1                   NaN                     NaT
# 2                   NaN              2019-11-08
# 3                   NaN                     NaT
# 4      Cannot Represent              2019-12-20
# ...                 ...                     ...
# 7671                NaN                     NaT
# 7672                NaN                     NaT
# 7673                NaN                     NaT
# 7674                NaN                     NaT
# 7675                NaN                     NaT
#
#                        Program Eligibilities Date of Referral First Referral  \
# 0             Vulnerability-Based Relocation       2019-07-25             No
# 1             Vulnerability-Based Relocation       2019-08-03             No
# 2     Vulnerability-Based RST and Protection       2019-08-08            Yes
# 3             Vulnerability-Based Relocation       2019-08-02             No
# 4             Vulnerability-Based Relocation       2019-08-02             No
# ...                                      ...              ...            ...
# 7671                                     NaN              NaT            NaN
# 7672                                     NaN              NaT            NaN
# 7673                                     NaN              NaT            NaN
# 7674                                     NaN              NaT            NaN
# 7675                                     NaN              NaT            NaN
#
#      In IRAP Process
# 0                 No
# 1                Yes
# 2                 No
# 3                 No
# 4                 No
# ...              ...
# 7671             NaN
# 7672             NaN
# 7673             NaN
# 7674             NaN
# 7675             NaN
#
# [7655 rows x 126 columns]

# %%
null_count = pd.Series.to_frame(cleaned.isna().sum())
# null_count.rename(columns={"0": "null_count"})
null_count.columns = ["null_counts"]
null_count["total_counts"] = cleaned.shape[0]
null_count["null_percent"] = np.round(null_count["null_counts"] / cleaned.shape[0] , 5)
null_count["dtype"] = pd.Series.to_frame(cleaned.dtypes)
null_count["sample_value"] = cleaned.mode()[:1].T
null_count.sort_values(['null_counts'],ascending = False)[:20]
# Out:
#                             null_counts  total_counts  null_percent  \
# Field:Handoff Timestamp            7170          7655       0.93664
# process_day_>=1                    6877          7655       0.89837
# process_days                       6869          7655       0.89732
# process_day_>=7                    6869          7655       0.89732
# Date of Screening Decision         6866          7655       0.89693
# Medical_X_LPPN                     6846          7655       0.89432
# Field:LPPN Score                   6840          7655       0.89353
# Screening Decision                 6833          7655       0.89262
# Client Location (Country)          6828          7655       0.89197
# Client Nationality                 6811          7655       0.88975
# Date of Screening Start            6630          7655       0.86610
# Program Eligibilities              6606          7655       0.86297
# Date of Referral                   6572          7655       0.85852
# In IRAP Process                    6570          7655       0.85826
# First Referral                     6570          7655       0.85826
# Field:Current Country              2735          7655       0.35728
# Field:Nationality1                 2680          7655       0.35010
# Field:Gender                       2534          7655       0.33103
# Language                           1055          7655       0.13782
# Created On                          199          7655       0.02600
#
#                                      dtype  \
# Field:Handoff Timestamp             object
# process_day_>=1                    float64
# process_days                       float64
# process_day_>=7                    float64
# Date of Screening Decision  datetime64[ns]
# Medical_X_LPPN                     float64
# Field:LPPN Score                   float64
# Screening Decision                  object
# Client Location (Country)           object
# Client Nationality                  object
# Date of Screening Start     datetime64[ns]
# Program Eligibilities               object
# Date of Referral            datetime64[ns]
# In IRAP Process                     object
# First Referral                      object
# Field:Current Country               object
# Field:Nationality1                  object
# Field:Gender                        object
# Language                            object
# Created On                  datetime64[ns]
#
#                                                       sample_value
# Field:Handoff Timestamp           2019-08-04 22:38:02.496664+03:00
# process_day_>=1                                                  0
# process_days                                                     0
# process_day_>=7                                                  0
# Date of Screening Decision                     2019-07-26 00:00:00
# Medical_X_LPPN                                                   0
# Field:LPPN Score                                                 0
# Screening Decision                                Cannot Represent
# Client Location (Country)                                  Lebanon
# Client Nationality                                          Syrian
# Date of Screening Start                        2019-07-26 00:00:00
# Program Eligibilities       Vulnerability-Based RST and Protection
# Date of Referral                               2019-08-05 00:00:00
# In IRAP Process                                                 No
# First Referral                                                 Yes
# Field:Current Country                                      Lebanon
# Field:Nationality1                                          Syrian
# Field:Gender                                                  Male
# Language                                                       ara
# Created On                                     2019-10-16 19:25:50

# %%
cleaned.to_csv("cleaned_data.csv")
